# %% [markdown]
# ## U-Net architecture

# %%
import os
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.preprocessing.image import load_img, img_to_array
from tensorflow.keras import backend as K
import cv2
import matplotlib.pyplot as plt
from datetime import datetime  # Import datetime for the custom callback
from sklearn.metrics import confusion_matrix, accuracy_score, recall_score, precision_score, f1_score
import seaborn as sns
from tensorflow.keras.callbacks import EarlyStopping  # Import EarlyStopping

# Directory paths
train_img_dir = r"C:\Users\Jaber\OneDrive - University of Florida\Educational\GitHub\Datasets\ImageSegmentation\Dental_XRay_Computacional_Vision_Segmentation\Dental X_Ray\train"
train_mask_dir = r"C:\Users\Jaber\OneDrive - University of Florida\Educational\GitHub\ImageSegmentation\Datasets\Dental_XRay_Computacional_Vision_Segmentation\Dental X_Ray\train\train_mask"
test_img_dir = r"C:\Users\Jaber\OneDrive - University of Florida\Educational\GitHub\Datasets\ImageSegmentation\Dental_XRay_Computacional_Vision_Segmentation\Dental X_Ray\test"
test_mask_dir = r"C:\Users\Jaber\OneDrive - University of Florida\Educational\GitHub\ImageSegmentation\Datasets\Dental_XRay_Computacional_Vision_Segmentation\Dental X_Ray\test\test_mask"
valid_img_dir = r"C:\Users\Jaber\OneDrive - University of Florida\Educational\GitHub\Datasets\ImageSegmentation\Dental_XRay_Computacional_Vision_Segmentation\Dental X_Ray\valid"
valid_mask_dir = r"C:\Users\Jaber\OneDrive - University of Florida\Educational\GitHub\ImageSegmentation\Datasets\Dental_XRay_Computacional_Vision_Segmentation\Dental X_Ray\valid\valid_mask"

# U-Net model
def unet_model(input_size=(256, 256, 1)):
    inputs = layers.Input(input_size)
    
    # Downsample
    c1 = layers.Conv2D(64, (3, 3), activation='relu', padding='same')(inputs)
    c1 = layers.Conv2D(64, (3, 3), activation='relu', padding='same')(c1)
    p1 = layers.MaxPooling2D((2, 2))(c1)

    c2 = layers.Conv2D(128, (3, 3), activation='relu', padding='same')(p1)
    c2 = layers.Conv2D(128, (3, 3), activation='relu', padding='same')(c2)
    p2 = layers.MaxPooling2D((2, 2))(c2)

    c3 = layers.Conv2D(256, (3, 3), activation='relu', padding='same')(p2)
    c3 = layers.Conv2D(256, (3, 3), activation='relu', padding='same')(c3)
    p3 = layers.MaxPooling2D((2, 2))(c3)

    c4 = layers.Conv2D(512, (3, 3), activation='relu', padding='same')(p3)
    c4 = layers.Conv2D(512, (3, 3), activation='relu', padding='same')(c4)
    p4 = layers.MaxPooling2D(pool_size=(2, 2))(c4)

    # Bottleneck
    c5 = layers.Conv2D(1024, (3, 3), activation='relu', padding='same')(p4)
    c5 = layers.Conv2D(1024, (3, 3), activation='relu', padding='same')(c5)

    # Upsample
    u6 = layers.Conv2DTranspose(512, (2, 2), strides=(2, 2), padding='same')(c5)
    u6 = layers.concatenate([u6, c4])
    c6 = layers.Conv2D(512, (3, 3), activation='relu', padding='same')(u6)
    c6 = layers.Conv2D(512, (3, 3), activation='relu', padding='same')(c6)

    u7 = layers.Conv2DTranspose(256, (2, 2), strides=(2, 2), padding='same')(c6)
    u7 = layers.concatenate([u7, c3])
    c7 = layers.Conv2D(256, (3, 3), activation='relu', padding='same')(u7)
    c7 = layers.Conv2D(256, (3, 3), activation='relu', padding='same')(c7)

    u8 = layers.Conv2DTranspose(128, (2, 2), strides=(2, 2), padding='same')(c7)
    u8 = layers.concatenate([u8, c2])
    c8 = layers.Conv2D(128, (3, 3), activation='relu', padding='same')(u8)
    c8 = layers.Conv2D(128, (3, 3), activation='relu', padding='same')(c8)

    u9 = layers.Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same')(c8)
    u9 = layers.concatenate([u9, c1], axis=3)
    c9 = layers.Conv2D(64, (3, 3), activation='relu', padding='same')(u9)
    c9 = layers.Conv2D(64, (3, 3), activation='relu', padding='same')(c9)

    outputs = layers.Conv2D(1, (1, 1), activation='sigmoid')(c9)

    model = models.Model(inputs=[inputs], outputs=[outputs])
    
    return model

# Load images and masks
def load_images_and_masks(img_dir, mask_dir, img_size=(256, 256)):
    images = []
    masks = []
    
    img_files = os.listdir(img_dir)
    for img_file in img_files:
        img_path = os.path.join(img_dir, img_file)
        # Adjust mask filename to include "_mask.png"
        mask_file = img_file + "_mask.png"
        mask_path = os.path.join(mask_dir, mask_file)

        if os.path.exists(mask_path):
            # Load image and mask
            img = load_img(img_path, color_mode='grayscale', target_size=img_size)
            img = img_to_array(img) / 255.0
            mask = load_img(mask_path, color_mode='grayscale', target_size=img_size)
            mask = img_to_array(mask) / 255.0

            images.append(img)
            masks.append(mask)
        else:
            print(f"Mask not found for {img_file}, skipping this image.")
    
    return np.array(images), np.array(masks)

# Load training and validation data
X_train, y_train = load_images_and_masks(train_img_dir, train_mask_dir)
X_valid, y_valid = load_images_and_masks(valid_img_dir, valid_mask_dir)

# Define custom metrics
def custom_precision(y_true, y_pred):
    y_pred_bin = K.round(y_pred)
    true_positives = K.sum(K.round(y_true * y_pred_bin))
    predicted_positives = K.sum(y_pred_bin)
    precision = true_positives / (predicted_positives + K.epsilon())
    return precision

def custom_recall(y_true, y_pred):
    y_pred_bin = K.round(y_pred)
    true_positives = K.sum(K.round(y_true * y_pred_bin))
    possible_positives = K.sum(y_true)
    recall = true_positives / (possible_positives + K.epsilon())
    return recall

def custom_specificity(y_true, y_pred):
    y_pred_bin = K.round(y_pred)
    true_negatives = K.sum(K.round((1 - y_true) * (1 - y_pred_bin)))
    possible_negatives = K.sum(1 - y_true)
    specificity = true_negatives / (possible_negatives + K.epsilon())
    return specificity

def custom_f1(y_true, y_pred):
    precision = custom_precision(y_true, y_pred)
    recall = custom_recall(y_true, y_pred)
    return 2 * (precision * recall) / (precision + recall + K.epsilon())

# Define Focal Loss
def focal_loss_fixed(y_true, y_pred):
    gamma = 2.0
    alpha = 0.25
    epsilon = K.epsilon()
    y_pred = K.clip(y_pred, epsilon, 1. - epsilon)
    cross_entropy = -y_true * K.log(y_pred) - (1 - y_true) * K.log(1 - y_pred)
    weight = alpha * y_true * K.pow((1 - y_pred), gamma) + (1 - alpha) * (1 - y_true) * K.pow(y_pred, gamma)
    loss = weight * cross_entropy
    return K.mean(loss)

# Compile the model
model = unet_model()
model.compile(optimizer='adam', loss=focal_loss_fixed, metrics=['accuracy', custom_precision, custom_recall, custom_specificity, custom_f1])

# Batch size for training
batch_size = 16

# Calculate total batches for training
total_batches = int(np.ceil(len(X_train) / batch_size))

# Custom callback to print more metrics at each batch
class MetricsCallback(tf.keras.callbacks.Callback):
    def __init__(self, total_batches):
        super().__init__()
        self.batch_counter = 1  # Initialize the batch counter
        self.total_batches = total_batches  # Total number of batches per epoch
        self.current_epoch = 1  # Initialize current epoch

    def on_epoch_begin(self, epoch, logs=None):
        self.current_epoch = epoch + 1  # Epochs are zero-indexed
        print(f"\nEpoch {self.current_epoch}/{self.params['epochs']}")

    def on_batch_end(self, batch, logs=None):
        logs = logs or {}
        accuracy = logs.get('accuracy', 0)
        loss = logs.get('loss', 0)
        precision = logs.get('custom_precision', 0)
        recall = logs.get('custom_recall', 0)
        f1 = logs.get('custom_f1', 0)
        specificity = logs.get('custom_specificity', 0)
        
        # Time formatting for current step
        current_time = datetime.now().strftime("%H:%M:%S")
        
        # Print the metrics with proper formatting
        print(f"Batch {self.batch_counter}/{self.total_batches} ━━━━━━━━━━━━━━━━━━━━ {current_time}")
        print(f"Accuracy: {accuracy:.4f} - Precision: {precision:.4f} - Recall: {recall:.4f} - Specificity: {specificity:.4f} - F1: {f1:.4f} - Loss: {loss:.4f}\n")
        
        # Increment batch counter
        self.batch_counter += 1

    def on_epoch_end(self, epoch, logs=None):
        # Reset batch counter at the end of each epoch
        self.batch_counter = 1

# Define early stopping
early_stopping = EarlyStopping(
    monitor='val_loss',        # Metric to monitor
    patience=5,                # Number of epochs with no improvement after which training will be stopped
    restore_best_weights=True  # Restore model weights from the epoch with the best value of the monitored metric
)

# Initialize the custom callback
metrics_callback = MetricsCallback(total_batches=total_batches)

# Train the model with early stopping
history = model.fit(
    X_train, y_train,
    epochs=20,               # Number of epochs
    batch_size=batch_size,   # Batch size of 16
    validation_data=(X_valid, y_valid),
    callbacks=[metrics_callback, early_stopping],  # Add early_stopping to the callbacks list
    verbose=0                # Suppress default Keras logging
)

# Save the model
model.save('dental_xray_unet_model.h5')

# Load test data
X_test, y_test = load_images_and_masks(test_img_dir, test_mask_dir)

# Evaluate on the training set
y_train_pred = model.predict(X_train, batch_size=batch_size)
y_train_pred_bin = (y_train_pred > 0.5).astype(np.uint8)

# Confusion Matrix for training
conf_matrix_train = confusion_matrix(y_train.flatten(), y_train_pred_bin.flatten())
plt.figure(figsize=(6, 4))
sns.heatmap(conf_matrix_train, annot=True, fmt="d", cmap="Blues")
plt.title("Confusion Matrix for Train")
plt.xlabel("Predicted")
plt.ylabel("True")
plt.show()

# Evaluate on the validation set
y_valid_pred = model.predict(X_valid, batch_size=batch_size)
y_valid_pred_bin = (y_valid_pred > 0.5).astype(np.uint8)

# Confusion Matrix for validation
conf_matrix_valid = confusion_matrix(y_valid.flatten(), y_valid_pred_bin.flatten())
plt.figure(figsize=(6, 4))
sns.heatmap(conf_matrix_valid, annot=True, fmt="d", cmap="Blues")
plt.title("Confusion Matrix for Validation")
plt.xlabel("Predicted")
plt.ylabel("True")
plt.show()

# Evaluate on the test set
y_test_pred = model.predict(X_test, batch_size=batch_size)
y_test_pred_bin = (y_test_pred > 0.5).astype(np.uint8)

# Confusion Matrix for testing
conf_matrix_test = confusion_matrix(y_test.flatten(), y_test_pred_bin.flatten())
plt.figure(figsize=(6, 4))
sns.heatmap(conf_matrix_test, annot=True, fmt="d", cmap="Blues")
plt.title("Confusion Matrix for Test")
plt.xlabel("Predicted")
plt.ylabel("True")
plt.show()

# Performance report for training set
train_accuracy = accuracy_score(y_train.flatten(), y_train_pred_bin.flatten())
train_recall = recall_score(y_train.flatten(), y_train_pred_bin.flatten())
train_precision = precision_score(y_train.flatten(), y_train_pred_bin.flatten())
train_f1 = f1_score(y_train.flatten(), y_train_pred_bin.flatten())
train_tn, train_fp, train_fn, train_tp = confusion_matrix(y_train.flatten(), y_train_pred_bin.flatten()).ravel()
train_specificity = train_tn / (train_tn + train_fp)

print(f'Training Set Results:')
print(f'Accuracy: {train_accuracy:.4f}')
print(f'Recall (Sensitivity): {train_recall:.4f}')
print(f'Precision: {train_precision:.4f}')
print(f'F1 Score: {train_f1:.4f}')
print(f'Specificity: {train_specificity:.4f}')

# Performance report for validation set
valid_accuracy = accuracy_score(y_valid.flatten(), y_valid_pred_bin.flatten())
valid_recall = recall_score(y_valid.flatten(), y_valid_pred_bin.flatten())
valid_precision = precision_score(y_valid.flatten(), y_valid_pred_bin.flatten())
valid_f1 = f1_score(y_valid.flatten(), y_valid_pred_bin.flatten())
valid_tn, valid_fp, valid_fn, valid_tp = confusion_matrix(y_valid.flatten(), y_valid_pred_bin.flatten()).ravel()
valid_specificity = valid_tn / (valid_tn + valid_fp)

print(f'Validation Set Results:')
print(f'Accuracy: {valid_accuracy:.4f}')
print(f'Recall (Sensitivity): {valid_recall:.4f}')
print(f'Precision: {valid_precision:.4f}')
print(f'F1 Score: {valid_f1:.4f}')
print(f'Specificity: {valid_specificity:.4f}')

# Performance report for testing set
test_accuracy = accuracy_score(y_test.flatten(), y_test_pred_bin.flatten())
test_recall = recall_score(y_test.flatten(), y_test_pred_bin.flatten())
test_precision = precision_score(y_test.flatten(), y_test_pred_bin.flatten())
test_f1 = f1_score(y_test.flatten(), y_test_pred_bin.flatten())
test_tn, test_fp, test_fn, test_tp = confusion_matrix(y_test.flatten(), y_test_pred_bin.flatten()).ravel()
test_specificity = test_tn / (test_tn + test_fp)

print(f'Testing Set Results:')
print(f'Accuracy: {test_accuracy:.4f}')
print(f'Recall (Sensitivity): {test_recall:.4f}')
print(f'Precision: {test_precision:.4f}')
print(f'F1 Score: {test_f1:.4f}')
print(f'Specificity: {test_specificity:.4f}')

# Visualization: Show input image, true mask, and predicted mask for a few samples
def visualize_predictions(images, true_masks, pred_masks, title):
    for i in range(3):  # Visualize first 3 predictions
        plt.figure(figsize=(12, 4))
        
        # Original image
        plt.subplot(1, 3, 1)
        plt.imshow(images[i].squeeze(), cmap='gray')
        plt.title('Original Image')
        
        # Ground truth mask
        plt.subplot(1, 3, 2)
        plt.imshow(true_masks[i].squeeze(), cmap='gray')
        plt.title('Ground Truth Mask')
        
        # Predicted mask
        plt.subplot(1, 3, 3)
        plt.imshow(pred_masks[i].squeeze(), cmap='gray')
        plt.title('Predicted Mask')
        
        plt.suptitle(title)
        plt.show()

# Visualize predictions for training set
visualize_predictions(X_train, y_train, y_train_pred_bin, "Train Set Predictions")

# Visualize predictions for validation set
visualize_predictions(X_valid, y_valid, y_valid_pred_bin, "Validation Set Predictions")

# Visualize predictions for testing set
visualize_predictions(X_test, y_test, y_test_pred_bin, "Test Set Predictions")
# Out:
# Mask not found for train_mask, skipping this image.
# Mask not found for valid_mask, skipping this image.
#
# Epoch 1/20
# Batch 1/299 ━━━━━━━━━━━━━━━━━━━━ 12:41:20
# Accuracy: 0.1233 - Precision: 0.0415 - Recall: 0.9663 - Specificity: 0.0888 - F1: 0.0796 - Loss: 0.1293
#
# Batch 2/299 ━━━━━━━━━━━━━━━━━━━━ 12:42:09
# Accuracy: 0.5499 - Precision: 0.0208 - Recall: 0.4831 - Specificity: 0.5444 - F1: 0.0398 - Loss: 0.1185
#
# Batch 3/299 ━━━━━━━━━━━━━━━━━━━━ 12:42:47
# Accuracy: 0.6912 - Precision: 0.0138 - Recall: 0.3221 - Specificity: 0.6963 - F1: 0.0265 - Loss: 0.1015
#
# Batch 4/299 ━━━━━━━━━━━━━━━━━━━━ 12:43:25
# Accuracy: 0.7590 - Precision: 0.0104 - Recall: 0.2416 - Specificity: 0.7722 - F1: 0.0199 - Loss: 0.0846
#
# Batch 5/299 ━━━━━━━━━━━━━━━━━━━━ 12:44:08
# Accuracy: 0.8026 - Precision: 0.0083 - Recall: 0.1933 - Specificity: 0.8178 - F1: 0.0159 - Loss: 0.0728
#
# Batch 6/299 ━━━━━━━━━━━━━━━━━━━━ 12:45:01
# Accuracy: 0.8313 - Precision: 0.0069 - Recall: 0.1610 - Specificity: 0.8481 - F1: 0.0133 - Loss: 0.0651
#
# Batch 7/299 ━━━━━━━━━━━━━━━━━━━━ 12:45:51
# Accuracy: 0.8505 - Precision: 0.0059 - Recall: 0.1380 - Specificity: 0.8698 - F1: 0.0114 - Loss: 0.0602
#
# Batch 8/299 ━━━━━━━━━━━━━━━━━━━━ 12:46:55
# Accuracy: 0.8644 - Precision: 0.0052 - Recall: 0.1208 - Specificity: 0.8861 - F1: 0.0099 - Loss: 0.0565
#
# Batch 9/299 ━━━━━━━━━━━━━━━━━━━━ 12:47:41
# Accuracy: 0.8771 - Precision: 0.0046 - Recall: 0.1074 - Specificity: 0.8988 - F1: 0.0088 - Loss: 0.0526
#
# Batch 10/299 ━━━━━━━━━━━━━━━━━━━━ 12:48:28
# Accuracy: 0.8875 - Precision: 0.0042 - Recall: 0.0966 - Specificity: 0.9089 - F1: 0.0080 - Loss: 0.0493
#
# Batch 11/299 ━━━━━━━━━━━━━━━━━━━━ 12:49:13
# Accuracy: 0.8960 - Precision: 0.0038 - Recall: 0.0878 - Specificity: 0.9172 - F1: 0.0072 - Loss: 0.0464
#
# Batch 12/299 ━━━━━━━━━━━━━━━━━━━━ 12:49:53
# Accuracy: 0.9028 - Precision: 0.0035 - Recall: 0.0805 - Specificity: 0.9241 - F1: 0.0066 - Loss: 0.0440
#
# Batch 13/299 ━━━━━━━━━━━━━━━━━━━━ 12:50:46
# Accuracy: 0.9082 - Precision: 0.0032 - Recall: 0.0743 - Specificity: 0.9299 - F1: 0.0061 - Loss: 0.0424
#
# Batch 14/299 ━━━━━━━━━━━━━━━━━━━━ 12:51:35
# Accuracy: 0.9132 - Precision: 0.0030 - Recall: 0.0690 - Specificity: 0.9349 - F1: 0.0057 - Loss: 0.0405
#
# Batch 15/299 ━━━━━━━━━━━━━━━━━━━━ 12:52:21
# Accuracy: 0.9172 - Precision: 0.0028 - Recall: 0.0644 - Specificity: 0.9393 - F1: 0.0053 - Loss: 0.0390
#
# Batch 16/299 ━━━━━━━━━━━━━━━━━━━━ 12:53:16
# Accuracy: 0.9203 - Precision: 0.0026 - Recall: 0.0604 - Specificity: 0.9431 - F1: 0.0050 - Loss: 0.0376
#
# Batch 17/299 ━━━━━━━━━━━━━━━━━━━━ 12:53:57
# Accuracy: 0.9239 - Precision: 0.0024 - Recall: 0.0568 - Specificity: 0.9464 - F1: 0.0047 - Loss: 0.0362
#
# Batch 18/299 ━━━━━━━━━━━━━━━━━━━━ 12:54:57
# Accuracy: 0.9261 - Precision: 0.0023 - Recall: 0.0537 - Specificity: 0.9494 - F1: 0.0044 - Loss: 0.0351
#
# Batch 19/299 ━━━━━━━━━━━━━━━━━━━━ 12:55:52
# Accuracy: 0.9289 - Precision: 0.0022 - Recall: 0.0509 - Specificity: 0.9520 - F1: 0.0042 - Loss: 0.0339
#
# Batch 20/299 ━━━━━━━━━━━━━━━━━━━━ 12:56:39
# Accuracy: 0.9314 - Precision: 0.0021 - Recall: 0.0483 - Specificity: 0.9544 - F1: 0.0040 - Loss: 0.0327
#
# Batch 21/299 ━━━━━━━━━━━━━━━━━━━━ 12:57:37
# Accuracy: 0.9338 - Precision: 0.0020 - Recall: 0.0460 - Specificity: 0.9566 - F1: 0.0038 - Loss: 0.0316
#
# Batch 22/299 ━━━━━━━━━━━━━━━━━━━━ 12:58:39
# Accuracy: 0.9357 - Precision: 0.0019 - Recall: 0.0439 - Specificity: 0.9586 - F1: 0.0036 - Loss: 0.0307
#
# Batch 23/299 ━━━━━━━━━━━━━━━━━━━━ 12:59:47
# Accuracy: 0.9378 - Precision: 0.0018 - Recall: 0.0420 - Specificity: 0.9604 - F1: 0.0035 - Loss: 0.0297
#
# Batch 24/299 ━━━━━━━━━━━━━━━━━━━━ 13:01:11
# Accuracy: 0.9392 - Precision: 0.0017 - Recall: 0.0403 - Specificity: 0.9620 - F1: 0.0033 - Loss: 0.0290

# %% [markdown]
# ## VGG16 architecture

# %%
import os
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.preprocessing.image import load_img, img_to_array
from tensorflow.keras import backend as K
import cv2
import matplotlib.pyplot as plt
from datetime import datetime  # Import datetime for the custom callback
from sklearn.metrics import confusion_matrix, accuracy_score, recall_score, precision_score, f1_score
import seaborn as sns
from tensorflow.keras.callbacks import EarlyStopping  # Import EarlyStopping
from tensorflow.keras.applications import VGG16  # Import VGG16 for the new model

# Directory paths
train_img_dir = r"C:\Users\Jaber\OneDrive - University of Florida\Educational\GitHub\Datasets\ImageSegmentation\Dental_XRay_Computacional_Vision_Segmentation\Dental X_Ray\train"
train_mask_dir = r"C:\Users\Jaber\OneDrive - University of Florida\Educational\GitHub\ImageSegmentation\Datasets\Dental_XRay_Computacional_Vision_Segmentation\Dental X_Ray\train\train_mask"
test_img_dir = r"C:\Users\Jaber\OneDrive - University of Florida\Educational\GitHub\Datasets\ImageSegmentation\Dental_XRay_Computacional_Vision_Segmentation\Dental X_Ray\test"
test_mask_dir = r"C:\Users\Jaber\OneDrive - University of Florida\Educational\GitHub\ImageSegmentation\Datasets\Dental_XRay_Computacional_Vision_Segmentation\Dental X_Ray\test\test_mask"
valid_img_dir = r"C:\Users\Jaber\OneDrive - University of Florida\Educational\GitHub\Datasets\ImageSegmentation\Dental_XRay_Computacional_Vision_Segmentation\Dental X_Ray\valid"
valid_mask_dir = r"C:\Users\Jaber\OneDrive - University of Florida\Educational\GitHub\ImageSegmentation\Datasets\Dental_XRay_Computacional_Vision_Segmentation\Dental X_Ray\valid\valid_mask"

# U-Net model replaced with VGG16-based model
def vgg16_unet_model(input_size=(256, 256, 3)):
    # Load VGG16 as the encoder with pre-trained ImageNet weights
    vgg16 = VGG16(include_top=False, weights='imagenet', input_shape=input_size)
    
    # Freeze VGG16 layers to prevent them from being trained
    for layer in vgg16.layers:
        layer.trainable = False
    
    # Extract layers for skip connections
    block1 = vgg16.get_layer('block1_pool').output   # 128x128
    block2 = vgg16.get_layer('block2_pool').output   # 64x64
    block3 = vgg16.get_layer('block3_pool').output   # 32x32
    block4 = vgg16.get_layer('block4_pool').output   # 16x16
    block5 = vgg16.get_layer('block5_pool').output   # 8x8
    
    # Decoder
    u6 = layers.Conv2DTranspose(512, (2, 2), strides=(2, 2), padding='same')(block5)  # 16x16
    u6 = layers.concatenate([u6, block4])
    c6 = layers.Conv2D(512, (3, 3), activation='relu', padding='same')(u6)
    c6 = layers.Conv2D(512, (3, 3), activation='relu', padding='same')(c6)
    
    u7 = layers.Conv2DTranspose(256, (2, 2), strides=(2, 2), padding='same')(c6)  # 32x32
    u7 = layers.concatenate([u7, block3])
    c7 = layers.Conv2D(256, (3, 3), activation='relu', padding='same')(u7)
    c7 = layers.Conv2D(256, (3, 3), activation='relu', padding='same')(c7)
    
    u8 = layers.Conv2DTranspose(128, (2, 2), strides=(2, 2), padding='same')(c7)  # 64x64
    u8 = layers.concatenate([u8, block2])
    c8 = layers.Conv2D(128, (3, 3), activation='relu', padding='same')(u8)
    c8 = layers.Conv2D(128, (3, 3), activation='relu', padding='same')(c8)
    
    u9 = layers.Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same')(c8)    # 128x128
    u9 = layers.concatenate([u9, block1])
    c9 = layers.Conv2D(64, (3, 3), activation='relu', padding='same')(u9)
    c9 = layers.Conv2D(64, (3, 3), activation='relu', padding='same')(c9)
    
    # Final upsampling to reach original image size
    u10 = layers.Conv2DTranspose(32, (2, 2), strides=(2, 2), padding='same')(c9)  # 256x256
    c10 = layers.Conv2D(32, (3, 3), activation='relu', padding='same')(u10)
    c10 = layers.Conv2D(32, (3, 3), activation='relu', padding='same')(c10)
    
    outputs = layers.Conv2D(1, (1, 1), activation='sigmoid')(c10)
    
    model = models.Model(inputs=vgg16.input, outputs=outputs)
    
    return model

# Load images and masks
def load_images_and_masks(img_dir, mask_dir, img_size=(256, 256)):
    images = []
    masks = []
    
    img_files = os.listdir(img_dir)
    for img_file in img_files:
        img_path = os.path.join(img_dir, img_file)
        # Adjust mask filename to include "_mask.png"
        mask_file = img_file + "_mask.png"
        mask_path = os.path.join(mask_dir, mask_file)

        if os.path.exists(mask_path):
            # Load image as RGB
            img = load_img(img_path, color_mode='rgb', target_size=img_size)
            img = img_to_array(img) / 255.0
            # Load mask as grayscale
            mask = load_img(mask_path, color_mode='grayscale', target_size=img_size)
            mask = img_to_array(mask) / 255.0

            images.append(img)
            masks.append(mask)
        else:
            print(f"Mask not found for {img_file}, skipping this image.")
    
    return np.array(images), np.array(masks)

# Load training and validation data
X_train, y_train = load_images_and_masks(train_img_dir, train_mask_dir)
X_valid, y_valid = load_images_and_masks(valid_img_dir, valid_mask_dir)

# Define custom metrics
def custom_precision(y_true, y_pred):
    y_pred_bin = K.round(y_pred)
    true_positives = K.sum(K.round(y_true * y_pred_bin))
    predicted_positives = K.sum(y_pred_bin)
    precision = true_positives / (predicted_positives + K.epsilon())
    return precision

def custom_recall(y_true, y_pred):
    y_pred_bin = K.round(y_pred)
    true_positives = K.sum(K.round(y_true * y_pred_bin))
    possible_positives = K.sum(y_true)
    recall = true_positives / (possible_positives + K.epsilon())
    return recall

def custom_specificity(y_true, y_pred):
    y_pred_bin = K.round(y_pred)
    true_negatives = K.sum(K.round((1 - y_true) * (1 - y_pred_bin)))
    possible_negatives = K.sum(1 - y_true)
    specificity = true_negatives / (possible_negatives + K.epsilon())
    return specificity

def custom_f1(y_true, y_pred):
    precision = custom_precision(y_true, y_pred)
    recall = custom_recall(y_true, y_pred)
    return 2 * (precision * recall) / (precision + recall + K.epsilon())

# Define Focal Loss
def focal_loss_fixed(y_true, y_pred):
    gamma = 2.0
    alpha = 0.25
    epsilon = K.epsilon()
    y_pred = K.clip(y_pred, epsilon, 1. - epsilon)
    cross_entropy = -y_true * K.log(y_pred) - (1 - y_true) * K.log(1 - y_pred)
    weight = alpha * y_true * K.pow((1 - y_pred), gamma) + (1 - alpha) * (1 - y_true) * K.pow(y_pred, gamma)
    loss = weight * cross_entropy
    return K.mean(loss)

# Compile the model
model = vgg16_unet_model()
model.compile(optimizer='adam', loss=focal_loss_fixed, metrics=['accuracy', custom_precision, custom_recall, custom_specificity, custom_f1])

# Batch size for training
batch_size = 16

# Calculate total batches for training
total_batches = int(np.ceil(len(X_train) / batch_size))

# Custom callback to print more metrics at each batch with epoch tracking
class MetricsCallback(tf.keras.callbacks.Callback):
    def __init__(self, total_batches):
        super().__init__()
        self.batch_counter = 1  # Initialize the batch counter
        self.total_batches = total_batches  # Total number of batches per epoch
        self.current_epoch = 1  # Initialize current epoch

    def on_epoch_begin(self, epoch, logs=None):
        self.current_epoch = epoch + 1  # Epochs are zero-indexed
        print(f"\nEpoch {self.current_epoch}/{self.params['epochs']}")

    def on_batch_end(self, batch, logs=None):
        logs = logs or {}
        accuracy = logs.get('accuracy', 0)
        loss = logs.get('loss', 0)
        precision = logs.get('custom_precision', 0)
        recall = logs.get('custom_recall', 0)
        f1 = logs.get('custom_f1', 0)
        specificity = logs.get('custom_specificity', 0)
        
        # Time formatting for current step
        current_time = datetime.now().strftime("%H:%M:%S")
        
        # Print the metrics with proper formatting
        print(f"Batch {self.batch_counter}/{self.total_batches} ━━━━━━━━━━━━━━━━━━━━ {current_time}")
        print(f"Accuracy: {accuracy:.4f} - Precision: {precision:.4f} - Recall: {recall:.4f} - Specificity: {specificity:.4f} - F1: {f1:.4f} - Loss: {loss:.4f}\n")
        
        # Increment batch counter
        self.batch_counter += 1

    def on_epoch_end(self, epoch, logs=None):
        # Reset batch counter at the end of each epoch
        self.batch_counter = 1

# Define early stopping
early_stopping = EarlyStopping(
    monitor='val_loss',        # Metric to monitor
    patience=5,                # Number of epochs with no improvement after which training will be stopped
    restore_best_weights=True  # Restore model weights from the epoch with the best value of the monitored metric
)

# Initialize the custom callback
metrics_callback = MetricsCallback(total_batches=total_batches)

# Train the model with early stopping
history = model.fit(
    X_train, y_train,
    epochs=20,               # Number of epochs
    batch_size=batch_size,   # Batch size of 16
    validation_data=(X_valid, y_valid),
    callbacks=[metrics_callback, early_stopping],  # Add early_stopping to the callbacks list
    verbose=0                # Suppress default Keras logging
)

# Save the model
model.save('dental_xray_vgg16_unet_model.h5')

# Load test data
X_test, y_test = load_images_and_masks(test_img_dir, test_mask_dir)

# Evaluate on the training set
y_train_pred = model.predict(X_train, batch_size=batch_size)
y_train_pred_bin = (y_train_pred > 0.5).astype(np.uint8)

# Confusion Matrix for training
conf_matrix_train = confusion_matrix(y_train.flatten(), y_train_pred_bin.flatten())
plt.figure(figsize=(6, 4))
sns.heatmap(conf_matrix_train, annot=True, fmt="d", cmap="Blues")
plt.title("Confusion Matrix for Train")
plt.xlabel("Predicted")
plt.ylabel("True")
plt.show()

# Evaluate on the validation set
y_valid_pred = model.predict(X_valid, batch_size=batch_size)
y_valid_pred_bin = (y_valid_pred > 0.5).astype(np.uint8)

# Confusion Matrix for validation
conf_matrix_valid = confusion_matrix(y_valid.flatten(), y_valid_pred_bin.flatten())
plt.figure(figsize=(6, 4))
sns.heatmap(conf_matrix_valid, annot=True, fmt="d", cmap="Blues")
plt.title("Confusion Matrix for Validation")
plt.xlabel("Predicted")
plt.ylabel("True")
plt.show()

# Evaluate on the test set
y_test_pred = model.predict(X_test, batch_size=batch_size)
y_test_pred_bin = (y_test_pred > 0.5).astype(np.uint8)

# Confusion Matrix for testing
conf_matrix_test = confusion_matrix(y_test.flatten(), y_test_pred_bin.flatten())
plt.figure(figsize=(6, 4))
sns.heatmap(conf_matrix_test, annot=True, fmt="d", cmap="Blues")
plt.title("Confusion Matrix for Test")
plt.xlabel("Predicted")
plt.ylabel("True")
plt.show()

# Performance report for training set
train_accuracy = accuracy_score(y_train.flatten(), y_train_pred_bin.flatten())
train_recall = recall_score(y_train.flatten(), y_train_pred_bin.flatten())
train_precision = precision_score(y_train.flatten(), y_train_pred_bin.flatten())
train_f1 = f1_score(y_train.flatten(), y_train_pred_bin.flatten())
train_tn, train_fp, train_fn, train_tp = confusion_matrix(y_train.flatten(), y_train_pred_bin.flatten()).ravel()
train_specificity = train_tn / (train_tn + train_fp)

print(f'Training Set Results:')
print(f'Accuracy: {train_accuracy:.4f}')
print(f'Recall (Sensitivity): {train_recall:.4f}')
print(f'Precision: {train_precision:.4f}')
print(f'F1 Score: {train_f1:.4f}')
print(f'Specificity: {train_specificity:.4f}')

# Performance report for validation set
valid_accuracy = accuracy_score(y_valid.flatten(), y_valid_pred_bin.flatten())
valid_recall = recall_score(y_valid.flatten(), y_valid_pred_bin.flatten())
valid_precision = precision_score(y_valid.flatten(), y_valid_pred_bin.flatten())
valid_f1 = f1_score(y_valid.flatten(), y_valid_pred_bin.flatten())
valid_tn, valid_fp, valid_fn, valid_tp = confusion_matrix(y_valid.flatten(), y_valid_pred_bin.flatten()).ravel()
valid_specificity = valid_tn / (valid_tn + valid_fp)

print(f'Validation Set Results:')
print(f'Accuracy: {valid_accuracy:.4f}')
print(f'Recall (Sensitivity): {valid_recall:.4f}')
print(f'Precision: {valid_precision:.4f}')
print(f'F1 Score: {valid_f1:.4f}')
print(f'Specificity: {valid_specificity:.4f}')

# Performance report for testing set
test_accuracy = accuracy_score(y_test.flatten(), y_test_pred_bin.flatten())
test_recall = recall_score(y_test.flatten(), y_test_pred_bin.flatten())
test_precision = precision_score(y_test.flatten(), y_test_pred_bin.flatten())
test_f1 = f1_score(y_test.flatten(), y_test_pred_bin.flatten())
test_tn, test_fp, test_fn, test_tp = confusion_matrix(y_test.flatten(), y_test_pred_bin.flatten()).ravel()
test_specificity = test_tn / (test_tn + test_fp)

print(f'Testing Set Results:')
print(f'Accuracy: {test_accuracy:.4f}')
print(f'Recall (Sensitivity): {test_recall:.4f}')
print(f'Precision: {test_precision:.4f}')
print(f'F1 Score: {test_f1:.4f}')
print(f'Specificity: {test_specificity:.4f}')

# Visualization: Show input image, true mask, and predicted mask for a few samples
def visualize_predictions(images, true_masks, pred_masks, title):
    for i in range(3):  # Visualize first 3 predictions
        plt.figure(figsize=(12, 4))
        
        # Original image
        plt.subplot(1, 3, 1)
        plt.imshow(images[i].squeeze(), cmap='gray')
        plt.title('Original Image')
        
        # Ground truth mask
        plt.subplot(1, 3, 2)
        plt.imshow(true_masks[i].squeeze(), cmap='gray')
        plt.title('Ground Truth Mask')
        
        # Predicted mask
        plt.subplot(1, 3, 3)
        plt.imshow(pred_masks[i].squeeze(), cmap='gray')
        plt.title('Predicted Mask')
        
        plt.suptitle(title)
        plt.show()

# Visualize predictions for training set
visualize_predictions(X_train, y_train, y_train_pred_bin, "Train Set Predictions")

# Visualize predictions for validation set
visualize_predictions(X_valid, y_valid, y_valid_pred_bin, "Validation Set Predictions")

# Visualize predictions for testing set
visualize_predictions(X_test, y_test, y_test_pred_bin, "Test Set Predictions")
# Out:
# Mask not found for 00cf39c1-Karaptiyan_Robert_50yo_13032021_185908_jpg.rf.98b2e72cb9a26e75d40df97e04473ada.jpg, skipping this image.
# Mask not found for 00cf39c1-Karaptiyan_Robert_50yo_13032021_185908_jpg.rf.d93e04580a7164c9e5c7ebcd57177f6a.jpg, skipping this image.
# Mask not found for 01b0dd74-Gazavandi_Neda_2022-05-14190158_jpg.rf.93976cb5376c518410a89cbbc608a0a8.jpg, skipping this image.
# Mask not found for 01b0dd74-Gazavandi_Neda_2022-05-14190158_jpg.rf.c541ae6c3887111f9276f4e214cad77a.jpg, skipping this image.
# Mask not found for 02b46381-Rezaee_Maryam_2022-06-12141528_jpg.rf.5cf06f7e1c083aea5dacd08898b4884d.jpg, skipping this image.
# Mask not found for 02b46381-Rezaee_Maryam_2022-06-12141528_jpg.rf.fee19d58b08b7543ef271cf35c5d8a0c.jpg, skipping this image.
# Mask not found for 0424a401-Edrispour_Seyedekhadijeh_2022-05-14193301_jpg.rf.61b0e8a7f66637d888d59af39e492da1.jpg, skipping this image.
# Mask not found for 0424a401-Edrispour_Seyedekhadijeh_2022-05-14193301_jpg.rf.c69df5fcc014662a2c668adf08785c8c.jpg, skipping this image.
# Mask not found for 047576e0-ROSHAN_HOSEYN_2020-08-19104705_jpg.rf.92bbad8cb22abf2126c2927a748d644c.jpg, skipping this image.
# Mask not found for 047576e0-ROSHAN_HOSEYN_2020-08-19104705_jpg.rf.ad908eccd27ca396766df2b24bc9d9b8.jpg, skipping this image.
# Mask not found for 08a3095b-Ghamkhari_pishe_Mohammad_hossein_8yo_07022021_142437_jpg.rf.390035b87a86c8d3794b69147def4935.jpg, skipping this image.
# Mask not found for 08a3095b-Ghamkhari_pishe_Mohammad_hossein_8yo_07022021_142437_jpg.rf.f3372bb294968c30803968c7ffcb7106.jpg, skipping this image.
# Mask not found for 093ca428-CHOPANI_MAHNAZ_2020-07-21161258_jpg.rf.8da6d56b653705d99dad90d6d9a8a000.jpg, skipping this image.
# Mask not found for 093ca428-CHOPANI_MAHNAZ_2020-07-21161258_jpg.rf.f945951cb1b10a9ca1596cef78514811.jpg, skipping this image.
# Mask not found for 0a4f2d22-Hematian_Fariba_57y_31052021_132542_jpg.rf.31ea84ed311476ead2936c7a151d49ec.jpg, skipping this image.
# Mask not found for 0a4f2d22-Hematian_Fariba_57y_31052021_132542_jpg.rf.6bfcf8cfb273a9a0767ea25499da98bc.jpg, skipping this image.
# Mask not found for 0bbd4b0b-Saiidi_Mohammaad_2022-06-12142504_jpg.rf.8d9e964ae4c5e0af1f8cdd4ea8f23f60.jpg, skipping this image.
# Mask not found for 0bbd4b0b-Saiidi_Mohammaad_2022-06-12142504_jpg.rf.f87caa7c940e1fe26e153ca294f818a8.jpg, skipping this image.
# Mask not found for 0cb54eba-GOLIJ_ALI_2020-05-27202749_jpg.rf.a4a13ff1c36f858cb80a9b5ab1c732e9.jpg, skipping this image.
# Mask not found for 0cb54eba-GOLIJ_ALI_2020-05-27202749_jpg.rf.e6662bcc184979b7c61fbea19f89e7e8.jpg, skipping this image.
# Mask not found for 0d220dea-Farasati_Simin_35yo_08062021_145847_jpg.rf.478a679c3667801fa26068e518dea362.jpg, skipping this image.
# Mask not found for 0d220dea-Farasati_Simin_35yo_08062021_145847_jpg.rf.ef2111246eee2ed3e565e0945aaa3112.jpg, skipping this image.
# Mask not found for 0d2df2d7-SABOHI_ZAHRA_2020-08-25101609_jpg.rf.62ac20e237602d7b442e1ed8a0118e67.jpg, skipping this image.
# Mask not found for 0d2df2d7-SABOHI_ZAHRA_2020-08-25101609_jpg.rf.fdcc45d56b5121e6274de7811669a5fe.jpg, skipping this image.
# Mask not found for 0eda48fc-MERIKH_DAVOD_2020-06-18122737_jpg.rf.acbf21f422d5113d45355a94ceb166ec.jpg, skipping this image.
# Mask not found for 0eda48fc-MERIKH_DAVOD_2020-06-18122737_jpg.rf.ebbaebd8c44e9ca55ab65e3184a2ecda.jpg, skipping this image.
# Mask not found for 0f43899f-GhAZANFARY_ZAHRA_2020-07-21110533_jpg.rf.3dad7cb727ba69c655bdb8bbaad12c3c.jpg, skipping this image.
# Mask not found for 0f43899f-GhAZANFARY_ZAHRA_2020-07-21110533_jpg.rf.60f7b80380dde6b766c898e77a22d220.jpg, skipping this image.
# Mask not found for 0f54b2e7-Sourman_shahi_Ahmad_2022-06-12141947_jpg.rf.984423f18c5c422f51e45d4c9d183ae4.jpg, skipping this image.
# Mask not found for 0f54b2e7-Sourman_shahi_Ahmad_2022-06-12141947_jpg.rf.9ce179cbd4c241942ee1d66e781224db.jpg, skipping this image.
# Mask not found for 1027090000-jpg_png_jpg.rf.333790ad9434fd3cc84fb45a5073ee23.jpg, skipping this image.
# Mask not found for 1027090000-jpg_png_jpg.rf.5ffd7caccc0380c5f74e78a9ad661a7e.jpg, skipping this image.
# Mask not found for 1045860000-jpg_png_jpg.rf.2d60e12d597e38e4cd3a9650d040529a.jpg, skipping this image.
# Mask not found for 1045860000-jpg_png_jpg.rf.8d2060bf0e6fdee70d120e8427492197.jpg, skipping this image.
# Mask not found for 1065440000-jpg_png_jpg.rf.d4d9855769cfbb2a34205a9e1272183f.jpg, skipping this image.
# Mask not found for 1065440000-jpg_png_jpg.rf.f2251c493e3d0d86f2c7e229b7416d9c.jpg, skipping this image.
# Mask not found for 1068310000-jpg_png_jpg.rf.496b6935521bed038320c2ae45a108a9.jpg, skipping this image.
# Mask not found for 1068310000-jpg_png_jpg.rf.e0eef0d21daf6bf73ee6a68aa1d22b9a.jpg, skipping this image.
# Mask not found for 1080320000-jpg_png_jpg.rf.230c2cb316f49bef58332455c1a9a3b4.jpg, skipping this image.
# Mask not found for 1080320000-jpg_png_jpg.rf.48a9e99a371df75686b2189369fdf34c.jpg, skipping this image.
# Mask not found for 1098260000-jpg_png_jpg.rf.26690b28e3d727bdce235afae3d14072.jpg, skipping this image.
# Mask not found for 1098260000-jpg_png_jpg.rf.3c4693abc6422cf1def85166970f2d46.jpg, skipping this image.
# Mask not found for 1133df31-Gholami_Zahra_27yo_08062021_145257_jpg.rf.7ad0b04f60a505e8195d7b6235e28a24.jpg, skipping this image.
# Mask not found for 1133df31-Gholami_Zahra_27yo_08062021_145257_jpg.rf.e789ab01b26d082c48f0e5e2337282e2.jpg, skipping this image.
# Mask not found for 1142690000-jpg_png_jpg.rf.9660c98b8f2a6b3860a040368154586c.jpg, skipping this image.
# Mask not found for 1142690000-jpg_png_jpg.rf.c1de4a4c00a8fffa65819d556ccebd7d.jpg, skipping this image.
# Mask not found for 11582aaa-Ebrahimi_Sirous_54y_31052021_111946_jpg.rf.00cb1ddf7d1d445dfebeafdc1159ec3b.jpg, skipping this image.
# Mask not found for 11582aaa-Ebrahimi_Sirous_54y_31052021_111946_jpg.rf.5a00de08901e0e6a9071c674f78e8661.jpg, skipping this image.
# Mask not found for 1162760000-jpg_png_jpg.rf.b460217ffbbe7d7b74946b7d60deb8ad.jpg, skipping this image.
# Mask not found for 1162760000-jpg_png_jpg.rf.d45e416d70b335fa30f651b45a7933f3.jpg, skipping this image.
# Mask not found for 1162860000-jpg_png_jpg.rf.2d4fe4e7ec91a07dd912229f82c2dfe0.jpg, skipping this image.
# Mask not found for 1162860000-jpg_png_jpg.rf.c41e0a527cad6fa6ce72d4452b5727c5.jpg, skipping this image.
# Mask not found for 118530000-jpg_png_jpg.rf.775f6a9aefa9d013077d6d87379fb049.jpg, skipping this image.
# Mask not found for 118530000-jpg_png_jpg.rf.812e159a8510795d4174290884549ff8.jpg, skipping this image.
# Mask not found for 1196060000-jpg_png_jpg.rf.6f65bfe06edaccd640ca7ad5fac43a08.jpg, skipping this image.
# Mask not found for 1196060000-jpg_png_jpg.rf.977b7ea6eaf8a369ec5bd6de11df6787.jpg, skipping this image.
# Mask not found for 1201670000-jpg_png_jpg.rf.bfc232e0aa6e5f806cfa79ec8f1becce.jpg, skipping this image.
# Mask not found for 1201670000-jpg_png_jpg.rf.ff816b92aea9a07fa0832fd5fb485077.jpg, skipping this image.
# Mask not found for 120dfa9b-JAFARNADERY_JAVID_2020-06-07092041_jpg.rf.4d29482009cf6bd0ea86555b3e90fd73.jpg, skipping this image.
# Mask not found for 120dfa9b-JAFARNADERY_JAVID_2020-06-07092041_jpg.rf.b04a4929c170088131a961e0cd8cf543.jpg, skipping this image.
# Mask not found for 1230940000-jpg_png_jpg.rf.b799288741c0ca9d03e227789fe96360.jpg, skipping this image.
# Mask not found for 1230940000-jpg_png_jpg.rf.bdfdfec689ee31fb75a1e1122ea9c133.jpg, skipping this image.
# Mask not found for 1241650000-jpg_png_jpg.rf.66e095ba7f480a7a3b608e135ed33bc3.jpg, skipping this image.
# Mask not found for 1241650000-jpg_png_jpg.rf.83e26f00caf0d44bee673c30ad757129.jpg, skipping this image.
# Mask not found for 1241720000-jpg_png_jpg.rf.80b2593c83e60095eff235a59a8b13c5.jpg, skipping this image.
# Mask not found for 1241720000-jpg_png_jpg.rf.e3019f9b2957a36f63d19bca68f50c6c.jpg, skipping this image.
# Mask not found for 1256540000-jpg_png_jpg.rf.95ea9ae754b51277ee285419ff0337f6.jpg, skipping this image.
# Mask not found for 1256540000-jpg_png_jpg.rf.fe5f25b45020da0b62a025b8573d7435.jpg, skipping this image.
# Mask not found for 126160000-jpg_png_jpg.rf.1223e22c2406ba9cdd22add368b3dd07.jpg, skipping this image.
# Mask not found for 126160000-jpg_png_jpg.rf.953e868a9394ef15e844f4e3e13a74b6.jpg, skipping this image.
# Mask not found for 1267600000-jpg_png_jpg.rf.861f10d4b4d2e8fdc2f38315fd6ee4a6.jpg, skipping this image.
# Mask not found for 1267600000-jpg_png_jpg.rf.be4b92cd59086328bc5a9ba12377d7ad.jpg, skipping this image.
# Mask not found for 12780c93-Parhizkar_Marziyeh_2022-06-12140432_jpg.rf.82fd0744beb84f973c44fabe703e4a93.jpg, skipping this image.
# Mask not found for 12780c93-Parhizkar_Marziyeh_2022-06-12140432_jpg.rf.8597cf22b1ce07bfdcf73335466c4cc5.jpg, skipping this image.
# Mask not found for 12800814-Behjoe_Mohammad_amin_12yo_02062021_102850_jpg.rf.392107555b5c06c1dc3b73e5870f7073.jpg, skipping this image.
# Mask not found for 12800814-Behjoe_Mohammad_amin_12yo_02062021_102850_jpg.rf.58881937839de9cdb74f3b5208db727c.jpg, skipping this image.
# Mask not found for 12f17961-Khalajamirhoseini_Hediyeh_2022-06-12140652_jpg.rf.a0a29ef5d50322be10d2db58b12f540f.jpg, skipping this image.
# Mask not found for 12f17961-Khalajamirhoseini_Hediyeh_2022-06-12140652_jpg.rf.dcc5ba567900a6a827f4b86f22a48e2c.jpg, skipping this image.
# Mask not found for 1304190000-jpg_png_jpg.rf.33c5bac0a86f2b4ae5c5849fb832eb63.jpg, skipping this image.
# Mask not found for 1304190000-jpg_png_jpg.rf.bc86f6acd9b2ed12f6e5a0b1909b9cc3.jpg, skipping this image.
# Mask not found for 1311600000-jpg_png_jpg.rf.9ad4764832a3fcd0379323c3d1de9769.jpg, skipping this image.
# Mask not found for 1311600000-jpg_png_jpg.rf.c70a2f2104546fcf96f3059bd8c201c0.jpg, skipping this image.
# Mask not found for 1317120000-jpg_png_jpg.rf.02ab0c2a1d9baa71a452a88f9fdd1315.jpg, skipping this image.
# Mask not found for 1317120000-jpg_png_jpg.rf.160f61cf50c3b9e70ec248bd3ed6d4dc.jpg, skipping this image.
# Mask not found for 1339590000-jpg_png_jpg.rf.b59de4903871eae9d8a345e59d573f4d.jpg, skipping this image.
# Mask not found for 1339590000-jpg_png_jpg.rf.fe732f3a76effc942a38bcc92ced3a45.jpg, skipping this image.
# Mask not found for 1349060000-jpg_png_jpg.rf.2aab87cbfa1709d47ab6e5a4b09b0a0b.jpg, skipping this image.
# Mask not found for 1349060000-jpg_png_jpg.rf.f0cb128c4d57c9e7702f75e41a3cc517.jpg, skipping this image.
# Mask not found for 134c09a8-NASIRI_FATEMEH_2020-06-24120642_jpg.rf.0d882c466c5cb2c8322b75935138fd6b.jpg, skipping this image.
# Mask not found for 134c09a8-NASIRI_FATEMEH_2020-06-24120642_jpg.rf.8a82b1c239744116adbbc527c600d6f5.jpg, skipping this image.
# Mask not found for 1366190000-jpg_png_jpg.rf.a82d45485872b3c5b491f77e0d700120.jpg, skipping this image.
# Mask not found for 1366190000-jpg_png_jpg.rf.bfcc6b8273a0ae3955f4139701a40bfb.jpg, skipping this image.
# Mask not found for 1379270000-jpg_png_jpg.rf.09beeeb940e2cc8c2ce31dd38bf96cd2.jpg, skipping this image.
# Mask not found for 1379270000-jpg_png_jpg.rf.d2cb45f89047f5cad43c3f86cc870311.jpg, skipping this image.
# Mask not found for 1390960000-jpg_png_jpg.rf.1d89aab6488c4a51b09a89e3beed619d.jpg, skipping this image.
# Mask not found for 1390960000-jpg_png_jpg.rf.3518153350c2290231bfc27bcae0da50.jpg, skipping this image.
# Mask not found for 1427260000-jpg_png_jpg.rf.6ce593a15da7c2bd05aca795756aab68.jpg, skipping this image.
# Mask not found for 1427260000-jpg_png_jpg.rf.76680763472b7199bd8593dd8d50798c.jpg, skipping this image.
# Mask not found for 1452650000-jpg_png_jpg.rf.1d73675b99c6c1afe90c2563abd81170.jpg, skipping this image.
# Mask not found for 1452650000-jpg_png_jpg.rf.732e7890276979c82c55f5359e413023.jpg, skipping this image.
# Mask not found for 1465740000-jpg_png_jpg.rf.3f9cd0b0f8c636f41e7c6c05f52cc084.jpg, skipping this image.
# Mask not found for 1465740000-jpg_png_jpg.rf.6d984025e363ccf8ffc0f126cb3bba15.jpg, skipping this image.
# Mask not found for 1487940000-jpg_png_jpg.rf.9955d39850f3b8b7e546bc6832114d00.jpg, skipping this image.
# Mask not found for 1487940000-jpg_png_jpg.rf.c0bf990b423d9ff3e7b367818e850b40.jpg, skipping this image.
# Mask not found for 1489970000-jpg_png_jpg.rf.87036f09bb3455dbf1663a53a0cf17e7.jpg, skipping this image.
# Mask not found for 1489970000-jpg_png_jpg.rf.c6c84e07fb37b2ec0ffffeb6f3d531a4.jpg, skipping this image.
# Mask not found for 14f7f895-Jalil_mazlaghani_Khalil_2022-06-12141554_jpg.rf.2c31ad646d33a515b3d146a5d60b52a2.jpg, skipping this image.
# Mask not found for 14f7f895-Jalil_mazlaghani_Khalil_2022-06-12141554_jpg.rf.da651ff706094a9fdf34979082704008.jpg, skipping this image.
# Mask not found for 1510350000-jpg_png_jpg.rf.b9f935d98aaca6e95dcc62f4ab339a91.jpg, skipping this image.
# Mask not found for 1510350000-jpg_png_jpg.rf.c6fe6f5177eaf217cdccaa6012d24b4d.jpg, skipping this image.
# Mask not found for 1510870000-jpg_png_jpg.rf.b28c1cd6ce5449e80fc1d1768a50f7ba.jpg, skipping this image.
# Mask not found for 1510870000-jpg_png_jpg.rf.e9b7eb109feebcc22cf0464d53044f59.jpg, skipping this image.
# Mask not found for 1511800000-jpg_png_jpg.rf.0e7c246f1e494a2d2ddbb67c5044de78.jpg, skipping this image.
# Mask not found for 1511800000-jpg_png_jpg.rf.b6d32a6c2c18dfd65896d37f3efa50a1.jpg, skipping this image.
# Mask not found for 1526950000-jpg_png_jpg.rf.6da426af53514bb35487281ce3e412fe.jpg, skipping this image.
# Mask not found for 1526950000-jpg_png_jpg.rf.f457dad10766d0441591d4bd035a494c.jpg, skipping this image.
# Mask not found for 1531560000-jpg_png_jpg.rf.ae4deae719a230b46faf132b4505f0f8.jpg, skipping this image.
# Mask not found for 1531560000-jpg_png_jpg.rf.d6a6210870e704d8deff17eaecf03eaa.jpg, skipping this image.
# Mask not found for 1534140000-jpg_png_jpg.rf.71b864498649f5fcc8203573c13b69ec.jpg, skipping this image.
# Mask not found for 1534140000-jpg_png_jpg.rf.c11d3761c05b6077c66ca20d153bb2d3.jpg, skipping this image.
# Mask not found for 1537080000-jpg_png_jpg.rf.0486a33000512118b28bf6f212cc79e1.jpg, skipping this image.
# Mask not found for 1537080000-jpg_png_jpg.rf.3c5184a0792b90419eb731b9f538ca68.jpg, skipping this image.
# Mask not found for 1544470000-jpg_png_jpg.rf.c457f89c1df4c41c18ad277e37f3f0f1.jpg, skipping this image.
# Mask not found for 1544470000-jpg_png_jpg.rf.d9f5ee62b0fd690c4c2d95aa2647511a.jpg, skipping this image.
# Mask not found for 1552180000-jpg_png_jpg.rf.ae299a3a18c2f34c9c3786a3db893199.jpg, skipping this image.
# Mask not found for 1552180000-jpg_png_jpg.rf.e6eef8cd3fdb00c65a1bb5da4ac68545.jpg, skipping this image.
# Mask not found for 1560590000-jpg_png_jpg.rf.2760f77ae276fe5ea822d18412a1dda9.jpg, skipping this image.
# Mask not found for 1560590000-jpg_png_jpg.rf.da7a702f4e8fefa869dc77557dfda616.jpg, skipping this image.
# Mask not found for 1567860000-jpg_png_jpg.rf.0f9cb1d5b899480a1e2d19444e5e0a8e.jpg, skipping this image.
# Mask not found for 1567860000-jpg_png_jpg.rf.a986c3f146d721febb44ed5b8195eaa3.jpg, skipping this image.
# Mask not found for 1575800000-jpg_png_jpg.rf.31ccc0c973f3caa18656555d89d728f9.jpg, skipping this image.
# Mask not found for 1575800000-jpg_png_jpg.rf.cf7ff99aef1121c8ed6784e4abefc441.jpg, skipping this image.
# Mask not found for 157920000-jpg_png_jpg.rf.103fb6462652ab7245f1e69294b243f2.jpg, skipping this image.
# Mask not found for 157920000-jpg_png_jpg.rf.8c90803ab1a943d4fa013d923e3b97cd.jpg, skipping this image.
# Mask not found for 1580720000-jpg_png_jpg.rf.247dc405327be15b8d6eb140e5a9b746.jpg, skipping this image.
# Mask not found for 1580720000-jpg_png_jpg.rf.8e070a24a9fa34e91ed2e25905c0931e.jpg, skipping this image.
# Mask not found for 1591140000-jpg_png_jpg.rf.b6c7e9c54c96a35f55732f6588d29d9a.jpg, skipping this image.
# Mask not found for 1591140000-jpg_png_jpg.rf.e9fbede2755ed98612be5b87b6585c8c.jpg, skipping this image.
# Mask not found for 1594390000-jpg_png_jpg.rf.5314d7a7dbc0e74abb883344f537e18a.jpg, skipping this image.
# Mask not found for 1594390000-jpg_png_jpg.rf.9b355a61910c01920de60f127e4a950b.jpg, skipping this image.
# Mask not found for 159700000-jpg_png_jpg.rf.6352aa73e0ecdf0346fb8cda2a92ee08.jpg, skipping this image.
# Mask not found for 159700000-jpg_png_jpg.rf.efd657ec87fbaad456f06591ef59b6d2.jpg, skipping this image.
# Mask not found for 1598060000-jpg_png_jpg.rf.7f854a4e8883bdde46e9bed0c43b09dd.jpg, skipping this image.
# Mask not found for 1598060000-jpg_png_jpg.rf.f66b3340fec979628576f2881a164c3c.jpg, skipping this image.
# Mask not found for 15e9be6f-ROSHANZAMIR_MASOMEH_2020-06-08112423_jpg.rf.170231f8787123a0d17a8b621c4613c4.jpg, skipping this image.
# Mask not found for 15e9be6f-ROSHANZAMIR_MASOMEH_2020-06-08112423_jpg.rf.48f9d263657e058089c6f3cc052c5bdb.jpg, skipping this image.
# Mask not found for 15e9be6f-ROSHANZAMIR_MASOMEH_2020-06-08112423_jpg.rf.a83e1bad0004673779469b82635f653c.jpg, skipping this image.
# Mask not found for 15e9be6f-ROSHANZAMIR_MASOMEH_2020-06-08112423_jpg.rf.cdafbc79a40beacb63b6fad61131c566.jpg, skipping this image.
# Mask not found for 1616000000-jpg_png_jpg.rf.1ea3787168e888f711bdf63f05507579.jpg, skipping this image.
# Mask not found for 1616000000-jpg_png_jpg.rf.b88a8882afc8f7e8282928e723af4392.jpg, skipping this image.
# Mask not found for 1625e3d5-Rezaee_Alireza_2022-06-12142256_jpg.rf.12697553cffdd51b28037e719dca6b17.jpg, skipping this image.
# Mask not found for 1625e3d5-Rezaee_Alireza_2022-06-12142256_jpg.rf.a108b4d7dd66731993f6bfc28374ad11.jpg, skipping this image.
# Mask not found for 1639290000-jpg_png_jpg.rf.c8552daaf820367545d1e67671359a14.jpg, skipping this image.
# Mask not found for 1639290000-jpg_png_jpg.rf.d81082f83217c8bfb78901e47d6692c8.jpg, skipping this image.
# Mask not found for 1651590000-jpg_png_jpg.rf.be0b84be0c82c6d19af31fee1c100060.jpg, skipping this image.
# Mask not found for 1651590000-jpg_png_jpg.rf.be3515d54106819381c038b788ee2c4b.jpg, skipping this image.
# Mask not found for 1681430000-jpg_png_jpg.rf.71d4e96da3c66aa5db0f79b4f046ab9f.jpg, skipping this image.
# Mask not found for 1681430000-jpg_png_jpg.rf.ba096195fa48c37629bd1b5eb141ea9a.jpg, skipping this image.
# Mask not found for 1715320000-jpg_png_jpg.rf.263b29cff8808daa93140d548ac074c9.jpg, skipping this image.
# Mask not found for 1715320000-jpg_png_jpg.rf.7766e0d200fd8c26a6bcb63ea42d7dd1.jpg, skipping this image.
# Mask not found for 1718440000-jpg_png_jpg.rf.6883d10c5673234bcaf881405b7f623f.jpg, skipping this image.
# Mask not found for 1718440000-jpg_png_jpg.rf.f764db4e8100d03f7359a2603f3aab2f.jpg, skipping this image.
# Mask not found for 1719420000-jpg_png_jpg.rf.2753adab32748fb2caba9e782eb0b538.jpg, skipping this image.
# Mask not found for 1719420000-jpg_png_jpg.rf.300edaa14025c7434fc02bdbbceeef7a.jpg, skipping this image.
# Mask not found for 1726350000-jpg_png_jpg.rf.2110f7a0c7254d0dca56524e2d3b1b34.jpg, skipping this image.
# Mask not found for 1726350000-jpg_png_jpg.rf.39d9850fc93fa3947fdc0692198573ef.jpg, skipping this image.
# Mask not found for 1732150000-jpg_png_jpg.rf.5c597ba3ca216f2c4ab186e0699a1e59.jpg, skipping this image.
# Mask not found for 1732150000-jpg_png_jpg.rf.c0c7503e02c063cafe134a7e60fbde2f.jpg, skipping this image.
# Mask not found for 1738890000-jpg_png_jpg.rf.a82faa48b25c9e074bfd1bf1485b2959.jpg, skipping this image.
# Mask not found for 1738890000-jpg_png_jpg.rf.b106065678473e440884a65c78450cb9.jpg, skipping this image.
# Mask not found for 1744990000-jpg_png_jpg.rf.307d43a17e46aee162e7056a1aa25a90.jpg, skipping this image.
# Mask not found for 1744990000-jpg_png_jpg.rf.381b2d3757bae240dac56d0d2f0abab4.jpg, skipping this image.
# Mask not found for 1745250000-jpg_png_jpg.rf.8004f4569bb55eebbe6cd5e2826ba758.jpg, skipping this image.
# Mask not found for 1745250000-jpg_png_jpg.rf.97d52a520bcfe2bff06cfd103748880a.jpg, skipping this image.
# Mask not found for 1755500000-jpg_png_jpg.rf.5293c1ac38018640131808cc636d81fc.jpg, skipping this image.
# Mask not found for 1755500000-jpg_png_jpg.rf.e35e21f0e4dee6a63d9bdb615437fdb5.jpg, skipping this image.
# Mask not found for 1762980000-jpg_png_jpg.rf.176f22d74adb2b367b2efe6b020c3be3.jpg, skipping this image.
# Mask not found for 1762980000-jpg_png_jpg.rf.c6b559df9886abef53bef5714d392ac7.jpg, skipping this image.
# Mask not found for 1767020000-jpg_png_jpg.rf.8f248312ed3311ff59dddb59a6853f58.jpg, skipping this image.
# Mask not found for 1767020000-jpg_png_jpg.rf.d343f07a91c00d0551b2336353c56ce5.jpg, skipping this image.
# Mask not found for 1780090000-jpg_png_jpg.rf.0246774c9637c777318f8935480108e0.jpg, skipping this image.
# Mask not found for 1780090000-jpg_png_jpg.rf.5100900d6f83f28f2b0a968469ba2dd6.jpg, skipping this image.
# Mask not found for 1792070000-jpg_png_jpg.rf.48c9033ca4bf8a8d236fcd9ef01f13e5.jpg, skipping this image.
# Mask not found for 1792070000-jpg_png_jpg.rf.71f1209e48830408589e2fce250ac77d.jpg, skipping this image.
# Mask not found for 1792690000-jpg_png_jpg.rf.320149d171fc05eb305f3f5a23d9da62.jpg, skipping this image.
# Mask not found for 1792690000-jpg_png_jpg.rf.c1deb47855cbdf933165a65208e705ed.jpg, skipping this image.
# Mask not found for 1796500000-jpg_png_jpg.rf.05dcc9b7f0bf8c56e30b090688779b3b.jpg, skipping this image.
# Mask not found for 1796500000-jpg_png_jpg.rf.d590371951cecd930efd913d87f6e6be.jpg, skipping this image.
# Mask not found for 1815920000-jpg_png_jpg.rf.37bed8395e8967926ec7b8b90b2ffeef.jpg, skipping this image.
# Mask not found for 1815920000-jpg_png_jpg.rf.f3036d574ce3162d43602a0a4c2defdc.jpg, skipping this image.
# Mask not found for 18173abd-khodabakhsh_Venisa_18yo_11102020_194137_jpg.rf.148d904e51d5cf6d44dad8b71f8db949.jpg, skipping this image.
# Mask not found for 18173abd-khodabakhsh_Venisa_18yo_11102020_194137_jpg.rf.d2ff6c9e5e9cfac2dd7172e5d2e017c9.jpg, skipping this image.
# Mask not found for 18173abd-khodabakhsh_Venisa_18yo_11102020_194137_jpg.rf.e2d0d689fe2d040f5d9637940003e3f3.jpg, skipping this image.
# Mask not found for 18173abd-khodabakhsh_Venisa_18yo_11102020_194137_jpg.rf.fdb2c49d9b4facd44d4370bc1988cab2.jpg, skipping this image.
# Mask not found for 1821140000-jpg_png_jpg.rf.3f76f861b3a03c8936147e4b29eae24b.jpg, skipping this image.
# Mask not found for 1821140000-jpg_png_jpg.rf.4a80afeeaf786812bf0e6e8c1e18bd43.jpg, skipping this image.
# Mask not found for 1827470000-jpg_png_jpg.rf.414c57de1d840a39a24ab0f843804b91.jpg, skipping this image.
# Mask not found for 1827470000-jpg_png_jpg.rf.6a23cf042455bf9f07ad444853e0581b.jpg, skipping this image.
# Mask not found for 1829290000-jpg_png_jpg.rf.3d58141dc52649d2fd32a97162e41374.jpg, skipping this image.
# Mask not found for 1829290000-jpg_png_jpg.rf.e74922a6fca609fe2a7e1bd3ae00c626.jpg, skipping this image.
# Mask not found for 1835950000-jpg_png_jpg.rf.3bf5411e20709af818054fba6dafc8f8.jpg, skipping this image.
# Mask not found for 1835950000-jpg_png_jpg.rf.b0d9b6c606193fb1b26399385f42485b.jpg, skipping this image.
# Mask not found for 1854600000-jpg_png_jpg.rf.1bb0242bec7210d13c6795ce0a05e05b.jpg, skipping this image.
# Mask not found for 1854600000-jpg_png_jpg.rf.4ae5a64be775375467bc7b61de0ffe0d.jpg, skipping this image.
# Mask not found for 1860230000-jpg_png_jpg.rf.176289d62c8533067e05b384e7b69e8e.jpg, skipping this image.
# Mask not found for 1860230000-jpg_png_jpg.rf.6cec1ab8c5b6575a0ec1a156e95a8606.jpg, skipping this image.
# Mask not found for 1877aba4-Nazari_Navid_2022-06-12141618_jpg.rf.653d2a66083504e9d258951be098a05e.jpg, skipping this image.
# Mask not found for 1877aba4-Nazari_Navid_2022-06-12141618_jpg.rf.fba4d9cecaac3f74c018ce1a237d49f0.jpg, skipping this image.
# Mask not found for 1883480000-jpg_png_jpg.rf.75c9ea4425a38a9a5365d51e168b1b78.jpg, skipping this image.
# Mask not found for 1883480000-jpg_png_jpg.rf.98ef94e3e48e3d8449e2c79993c09ed6.jpg, skipping this image.
# Mask not found for 18c3a518-IMANI_MOHAMMAD_2020-06-16104403_jpg.rf.3905afa6a596a4bb9da6be69abaf8d58.jpg, skipping this image.
# Mask not found for 18c3a518-IMANI_MOHAMMAD_2020-06-16104403_jpg.rf.6f4f72e36fc3eb45822f220929fd76fd.jpg, skipping this image.
# Mask not found for 18d6b97a-SARKARVAKILI_MEHRI_2020-06-21121217_jpg.rf.1719e0d98add34d5dd98e696fed84f82.jpg, skipping this image.
# Mask not found for 18d6b97a-SARKARVAKILI_MEHRI_2020-06-21121217_jpg.rf.28a5e8bf71a84fbdc04bb24a7d8ab9cf.jpg, skipping this image.
# Mask not found for 18d6b97a-SARKARVAKILI_MEHRI_2020-06-21121217_jpg.rf.5dcfaf42045deceb7727e063af840f80.jpg, skipping this image.
# Mask not found for 18d6b97a-SARKARVAKILI_MEHRI_2020-06-21121217_jpg.rf.919935d022eb207fd532ee7ce073adb3.jpg, skipping this image.
# Mask not found for 1919470000-jpg_png_jpg.rf.f099d5c2375ac9356ac52af4bcb5b027.jpg, skipping this image.
# Mask not found for 1919470000-jpg_png_jpg.rf.f839e5d8d1663d7ea90b6f105b47a39c.jpg, skipping this image.
# Mask not found for 1921760000-jpg_png_jpg.rf.33b84b2f7d701e374db7f30b58d04b5c.jpg, skipping this image.
# Mask not found for 1921760000-jpg_png_jpg.rf.e47858f0f67dcd824d05fd312bf3a809.jpg, skipping this image.
# Mask not found for 1921820000-jpg_png_jpg.rf.032f56d419d2c94af575fa2bf4241b2c.jpg, skipping this image.
# Mask not found for 1921820000-jpg_png_jpg.rf.845276a0453aa024e0915b570d232c29.jpg, skipping this image.
# Mask not found for 1933700000-jpg_png_jpg.rf.a01887e6a63476cff34b01b140da49dc.jpg, skipping this image.
# Mask not found for 1933700000-jpg_png_jpg.rf.f85d30544563f6b352dd9e5975867d32.jpg, skipping this image.
# Mask not found for 1951370000-jpg_png_jpg.rf.ae64bbb601385412f47c23e161793e47.jpg, skipping this image.
# Mask not found for 1951370000-jpg_png_jpg.rf.f295a26bcdbb35cbefb399020df2bd7b.jpg, skipping this image.
# Mask not found for 1968410000-jpg_png_jpg.rf.a07aeebacba67ff318619f338f368faa.jpg, skipping this image.
# Mask not found for 1968410000-jpg_png_jpg.rf.fecb2cb82b8645a1cb5417b9a30d53ed.jpg, skipping this image.
# Mask not found for 1968970000-jpg_png_jpg.rf.1eba2ab4b135aa4ece0ce7598a005e7e.jpg, skipping this image.
# Mask not found for 1968970000-jpg_png_jpg.rf.29e94ae098ecdb4bc366c274e0e9ff91.jpg, skipping this image.
# Mask not found for 197030000-jpg_png_jpg.rf.3b51ab24ac8cb3f7e1b4a268037f789a.jpg, skipping this image.
# Mask not found for 197030000-jpg_png_jpg.rf.d4ecd403d99bb4d949b6c2adcb1f61cd.jpg, skipping this image.
# Mask not found for 1977090000-jpg_png_jpg.rf.537c117f1c867e1f7a49323e94883e88.jpg, skipping this image.
# Mask not found for 1977090000-jpg_png_jpg.rf.f584d57b7052cf9dd09ae4b901830e9b.jpg, skipping this image.
# Mask not found for 197850000-jpg_png_jpg.rf.39513d66a17a74673123d3b19d7ad85f.jpg, skipping this image.
# Mask not found for 197850000-jpg_png_jpg.rf.97ca19edb1be462c53a78a300b5f5d2d.jpg, skipping this image.
# Mask not found for 1981030000-jpg_png_jpg.rf.69e2d753e5d8cf420b478ab2e2cedd52.jpg, skipping this image.
# Mask not found for 1981030000-jpg_png_jpg.rf.8502d9a6f3753913e3b33bf33c039eea.jpg, skipping this image.
# Mask not found for 1983300000-jpg_png_jpg.rf.848c04d24c8a233c3913bff08af083be.jpg, skipping this image.
# Mask not found for 1983300000-jpg_png_jpg.rf.ce6d1850c6a16f67ae83ce1154292199.jpg, skipping this image.
# Mask not found for 1985410000-jpg_png_jpg.rf.edb03420452a6e66805c32f3a9673701.jpg, skipping this image.
# Mask not found for 1985410000-jpg_png_jpg.rf.fbf62567a72fe628afaac11fb31e9857.jpg, skipping this image.
# Mask not found for 19eaed2b-Hoseyniyoun_Abdolhoseyn_55y_31052021_165559_jpg.rf.62e5ce5e74dfbe1e38b1589c5205b525.jpg, skipping this image.
# Mask not found for 19eaed2b-Hoseyniyoun_Abdolhoseyn_55y_31052021_165559_jpg.rf.e7b331aa3d9604d20a27fb6fecf1f033.jpg, skipping this image.
# Mask not found for 1a416acc-Faraji_Amir_hoseyn_39yo_01062021_193211_jpg.rf.17a22c3307a401449522d5958b6eebd7.jpg, skipping this image.
# Mask not found for 1a416acc-Faraji_Amir_hoseyn_39yo_01062021_193211_jpg.rf.a11d0e73f3d40807191b07c8a924dcfb.jpg, skipping this image.
# Mask not found for 1aa635ec-Solati_Alamtaj_2022-06-12140737_jpg.rf.2e564fb56b8360e3eca5f6b992894005.jpg, skipping this image.
# Mask not found for 1aa635ec-Solati_Alamtaj_2022-06-12140737_jpg.rf.b123e071f2f1311875cc443c4fcc2c09.jpg, skipping this image.
# Mask not found for 1c074580-Motedayen_Zahra_2022-06-12140835_jpg.rf.400930859c6d7308f959c720dc3b870f.jpg, skipping this image.
# Mask not found for 1c074580-Motedayen_Zahra_2022-06-12140835_jpg.rf.c69f5bd968005ac23455ed3d24742841.jpg, skipping this image.
# Mask not found for 1e7ba314-Ataee_pour_Mostafa_2022-06-12140708_jpg.rf.6c77908395817ed1757990c4b9fa57cd.jpg, skipping this image.
# Mask not found for 1e7ba314-Ataee_pour_Mostafa_2022-06-12140708_jpg.rf.a8b91305338e8f2f664950eba9ed956d.jpg, skipping this image.
# Mask not found for 1fa3900a-Fathizade_Kazhal_36yo_01062021_154836_jpg.rf.0d82f111e55d9628a37062c3ddda3277.jpg, skipping this image.
# Mask not found for 1fa3900a-Fathizade_Kazhal_36yo_01062021_154836_jpg.rf.255ad9200a43ac03adc2a3688d821677.jpg, skipping this image.
# Mask not found for 2005880000-jpg_png_jpg.rf.8ac2a74a3bef3e39470586d24e34f3a7.jpg, skipping this image.
# Mask not found for 2005880000-jpg_png_jpg.rf.d97c39c5709c3a0136a91c85084a884e.jpg, skipping this image.
# Mask not found for 2012780000-jpg_png_jpg.rf.0b0f2e352ed639011e11c5da14e7ddc1.jpg, skipping this image.
# Mask not found for 2012780000-jpg_png_jpg.rf.b8d1938db78a14afe8b5920612816873.jpg, skipping this image.
# Mask not found for 2014170000-jpg_png_jpg.rf.bbbca63a2ea7327b7b437112aa9349d8.jpg, skipping this image.
# Mask not found for 2014170000-jpg_png_jpg.rf.dae3cc31eb506a83c5098a1c81c6b98c.jpg, skipping this image.
# Mask not found for 2059990000-jpg_png_jpg.rf.0aaab283310af4f8052df062d42859b0.jpg, skipping this image.
# Mask not found for 2059990000-jpg_png_jpg.rf.9cb932cd24fb1964d0670d7ee4a54aff.jpg, skipping this image.
# Mask not found for 2061100000-jpg_png_jpg.rf.d40b30bfebf8506dc35d582ac609f3f3.jpg, skipping this image.
# Mask not found for 2061100000-jpg_png_jpg.rf.d61d6253da09b7e54e66bb4f4ae64c19.jpg, skipping this image.
# Mask not found for 2080220000-jpg_png_jpg.rf.da1da8d1feecad842f8e59cbf372e8aa.jpg, skipping this image.
# Mask not found for 2080220000-jpg_png_jpg.rf.fa592015b287768b8c22f1a2d0ef49e6.jpg, skipping this image.
# Mask not found for 2089150000-jpg_png_jpg.rf.0c14c6e1a0e2ee5e4e1cdd58a424bb3c.jpg, skipping this image.
# Mask not found for 2089150000-jpg_png_jpg.rf.a76eb811d659e7d16764d1476078485a.jpg, skipping this image.
# Mask not found for 2095880000-jpg_png_jpg.rf.109dd1be41ac1de0f1bbd7854fcd8bc5.jpg, skipping this image.
# Mask not found for 2095880000-jpg_png_jpg.rf.8eab1f85538d1497cc02c4872969c884.jpg, skipping this image.
# Mask not found for 2108630000-jpg_png_jpg.rf.a985034f50965ea0bfcb02c6a96e59c6.jpg, skipping this image.
# Mask not found for 2108630000-jpg_png_jpg.rf.f0fb5d9bae9e8d3fb49d46c21b274d28.jpg, skipping this image.
# Mask not found for 2116170000-jpg_png_jpg.rf.3db915b66291b7f294d3f86065d4cc34.jpg, skipping this image.
# Mask not found for 2116170000-jpg_png_jpg.rf.51df4597f90aef93ac5c34f827e4479e.jpg, skipping this image.
# Mask not found for 2121980000-jpg_png_jpg.rf.3024c86be23cab0bd6d8cc8bd23ad764.jpg, skipping this image.
# Mask not found for 2121980000-jpg_png_jpg.rf.7b020ba66e341c6eb8efd35efdf21574.jpg, skipping this image.
# Mask not found for 2126380000-jpg_png_jpg.rf.12cd3a8291ef5b4dec817b51a0e434f5.jpg, skipping this image.
# Mask not found for 2126380000-jpg_png_jpg.rf.b3116ed12b5ecb68b1a39c31464b9542.jpg, skipping this image.
# Mask not found for 2140080000-jpg_png_jpg.rf.db77c9cc5f014b64a08b6c39b6c7b96a.jpg, skipping this image.
# Mask not found for 2140080000-jpg_png_jpg.rf.f86b1732fd5f83162e90682d8d784c44.jpg, skipping this image.
# Mask not found for 2145590000-jpg_png_jpg.rf.3f22875927cfc86863ac24e3416f86c2.jpg, skipping this image.
# Mask not found for 2145590000-jpg_png_jpg.rf.58e63186f60174d1ea1126fdde433f71.jpg, skipping this image.
# Mask not found for 2145770000-jpg_png_jpg.rf.52306571309709600c9e6ad27ea4fa03.jpg, skipping this image.
# Mask not found for 2145770000-jpg_png_jpg.rf.d7d87316e56ef8ed9a33046ecfa54bdb.jpg, skipping this image.
# Mask not found for 2165250000-jpg_png_jpg.rf.9e444da11504e7d3b6f52fd47f6da04f.jpg, skipping this image.
# Mask not found for 2165250000-jpg_png_jpg.rf.d9f4de9c38fbafb43fe1ef2d38ea4628.jpg, skipping this image.
# Mask not found for 2185330000-jpg_png_jpg.rf.06ebea5c877fcd6a76d228f3c3ea7cdd.jpg, skipping this image.
# Mask not found for 2185330000-jpg_png_jpg.rf.d4a1e69e3725c81fa6c6d1ab23c02cef.jpg, skipping this image.
# Mask not found for 2198290000-jpg_png_jpg.rf.0e5732da5f3201728ac6791b339572cb.jpg, skipping this image.
# Mask not found for 2198290000-jpg_png_jpg.rf.cea5495204125efb271655cfbd209445.jpg, skipping this image.
# Mask not found for 2205630000-jpg_png_jpg.rf.04d31ce2a8fc32fe835f0a963b1e45cf.jpg, skipping this image.
# Mask not found for 2205630000-jpg_png_jpg.rf.ac78eb580a70008ff0f2d4082b78b551.jpg, skipping this image.
# Mask not found for 2212890000-jpg_png_jpg.rf.3375d54a859d0442596f7cd7c0a573e7.jpg, skipping this image.
# Mask not found for 2212890000-jpg_png_jpg.rf.e2289653377b57bd8fa39db6f55f1b6d.jpg, skipping this image.
# Mask not found for 221368bc-MIRZAI_AKBAR_2020-06-10193331_jpg.rf.cb1993afad7266fbe89ed8181aae7d4e.jpg, skipping this image.
# Mask not found for 221368bc-MIRZAI_AKBAR_2020-06-10193331_jpg.rf.db2cfc7826343308bdf91234fd9e41b3.jpg, skipping this image.
# Mask not found for 2242570000-jpg_png_jpg.rf.79a439a64af642dd57f117948795048a.jpg, skipping this image.
# Mask not found for 2242570000-jpg_png_jpg.rf.7bd871ab6a74b6b29705706fccb1e9ee.jpg, skipping this image.
# Mask not found for 2250840000-jpg_png_jpg.rf.89d3f2a03d822676446180b129a28d80.jpg, skipping this image.
# Mask not found for 2250840000-jpg_png_jpg.rf.dfd65cea113e263800fae537686a2324.jpg, skipping this image.
# Mask not found for 2260580000-jpg_png_jpg.rf.48c5c4b3facacfbd2a44220edf62eee5.jpg, skipping this image.
# Mask not found for 2260580000-jpg_png_jpg.rf.c1f6776c5b1375863762981bf2d05b29.jpg, skipping this image.
# Mask not found for 2264820000-jpg_png_jpg.rf.413b4726c87067b03e6e4bd54d7edf82.jpg, skipping this image.
# Mask not found for 2264820000-jpg_png_jpg.rf.725d0546cb93ee2e9c621e846de3bfd5.jpg, skipping this image.
# Mask not found for 2286070000-jpg_png_jpg.rf.93f0037029fb53b88c7d4f887c8c1266.jpg, skipping this image.
# Mask not found for 2286070000-jpg_png_jpg.rf.c12c72ad4b834a0932cba67a580c8cbb.jpg, skipping this image.
# Mask not found for 2286470000-jpg_png_jpg.rf.5f82b4a8c7a5d68a4dbc7851d111bcd4.jpg, skipping this image.
# Mask not found for 2286470000-jpg_png_jpg.rf.9d59af98e8acfa4162c75eada84969eb.jpg, skipping this image.
# Mask not found for 2304190000-jpg_png_jpg.rf.bdc2f558db267dcfdab9bb669be835cb.jpg, skipping this image.
# Mask not found for 2304190000-jpg_png_jpg.rf.e3e4338f246067f0bfc023f5ddd7d090.jpg, skipping this image.
# Mask not found for 2308600000-jpg_png_jpg.rf.09b0be10797304c4a4e442bc9ef1acfc.jpg, skipping this image.
# Mask not found for 2308600000-jpg_png_jpg.rf.9dd187fc277c006206ae1aa24d13fea4.jpg, skipping this image.
# Mask not found for 2332170000-jpg_png_jpg.rf.45fd5abcf36320379ea5859e9d7fec08.jpg, skipping this image.
# Mask not found for 2332170000-jpg_png_jpg.rf.ae352c1611dbe89ecbe940b479396b26.jpg, skipping this image.
# Mask not found for 2360920000-jpg_png_jpg.rf.15015ea828b0c9398f0c3cb0b83b494b.jpg, skipping this image.
# Mask not found for 2360920000-jpg_png_jpg.rf.8616ecf3ec336f5858ee769377a4c30d.jpg, skipping this image.
# Mask not found for 2376650000-jpg_png_jpg.rf.663d2138ca56b07f4cd0abf3fcd00d7c.jpg, skipping this image.
# Mask not found for 2376650000-jpg_png_jpg.rf.df7a8cddf475ae96ff5c517bda5fc769.jpg, skipping this image.
# Mask not found for 2391560000-jpg_png_jpg.rf.6f96191e7d82aa231d287a787bee25d8.jpg, skipping this image.
# Mask not found for 2391560000-jpg_png_jpg.rf.be72d4c471b22dbcc2dfade3a165c94b.jpg, skipping this image.
# Mask not found for 2398570000-jpg_png_jpg.rf.516d187cc5fbe8a10a78333f8ce1662b.jpg, skipping this image.
# Mask not found for 2398570000-jpg_png_jpg.rf.9d7273f1f8c181f65de12f2c083c7e08.jpg, skipping this image.
# Mask not found for 2400180000-jpg_png_jpg.rf.11238c37480fa32f15511ddc4b60bd91.jpg, skipping this image.
# Mask not found for 2400180000-jpg_png_jpg.rf.beb5d513727325f2b1c89ef72bc325b0.jpg, skipping this image.
# Mask not found for 2405470000-jpg_png_jpg.rf.3ed796ec37fd88511cfbc0a5bea6cc3f.jpg, skipping this image.
# Mask not found for 2405470000-jpg_png_jpg.rf.a61121ee7e9020775cc819afbe7c84a1.jpg, skipping this image.
# Mask not found for 2423320000-jpg_png_jpg.rf.72d90107f0fc0a4cb524edd42adb5dfa.jpg, skipping this image.
# Mask not found for 2423320000-jpg_png_jpg.rf.89abfaad65f817ab67b327d2d04be556.jpg, skipping this image.
# Mask not found for 2425480000-jpg_png_jpg.rf.683bc4d50281324e87752c556a1eec8d.jpg, skipping this image.
# Mask not found for 2425480000-jpg_png_jpg.rf.a2b87b7a53a0baab2946a5b0ab32a260.jpg, skipping this image.
# Mask not found for 242fce39-Godarzi_Ferdos_2022-06-12142243_jpg.rf.2a0c95686bdedf5f3efb133e17f817c0.jpg, skipping this image.
# Mask not found for 242fce39-Godarzi_Ferdos_2022-06-12142243_jpg.rf.97acfc5412e81da39e1630b3d19bc235.jpg, skipping this image.
# Mask not found for 2443730000-jpg_png_jpg.rf.2fd0f1636a84f7ced90c430524b9f08b.jpg, skipping this image.
# Mask not found for 2443730000-jpg_png_jpg.rf.47ff555f21529631b192183a867526b9.jpg, skipping this image.
# Mask not found for 2468620000-jpg_png_jpg.rf.57378505a6977bcee049291211f60fee.jpg, skipping this image.
# Mask not found for 2468620000-jpg_png_jpg.rf.be06348d4c867a79d400afc490a6f632.jpg, skipping this image.
# Mask not found for 2486950000-jpg_png_jpg.rf.8523e040b4f7f871483a30f48d8291aa.jpg, skipping this image.
# Mask not found for 2486950000-jpg_png_jpg.rf.e38f8df1e6b13c07365789656f194007.jpg, skipping this image.
# Mask not found for 2498580000-jpg_png_jpg.rf.356d76218929271f60560675d5533949.jpg, skipping this image.
# Mask not found for 2498580000-jpg_png_jpg.rf.b7cc628907403bb9e664e911227d2b0f.jpg, skipping this image.
# Mask not found for 249993e5-HEMMATI_AMIRABBAS_2020-08-18130608_jpg.rf.275d3a6e3d32866d31e277ef3c57f99d.jpg, skipping this image.
# Mask not found for 249993e5-HEMMATI_AMIRABBAS_2020-08-18130608_jpg.rf.d6ed4f3a3f135b38fd8ba4dc79ea7ab7.jpg, skipping this image.
# Mask not found for 24ea321e-HEYDARY_ZAHRA_2020-07-12112608_jpg.rf.9790c77ff7aba7083ae4fd2599be5657.jpg, skipping this image.
# Mask not found for 24ea321e-HEYDARY_ZAHRA_2020-07-12112608_jpg.rf.f0e8a603ac0a8608874b046f281fde24.jpg, skipping this image.
# Mask not found for 24f61afc-FARHAD_NARJES_2020-06-13195857_jpg.rf.06ed40ae93eacb0e3dfbc45d0c311565.jpg, skipping this image.
# Mask not found for 24f61afc-FARHAD_NARJES_2020-06-13195857_jpg.rf.e6162e0b5cd4f03b0a5a37e600e449c7.jpg, skipping this image.
# Mask not found for 2514420000-jpg_png_jpg.rf.2c126a136eb3586fe75480f354729976.jpg, skipping this image.
# Mask not found for 2514420000-jpg_png_jpg.rf.97c041826e6c2b502cb6fab4278d30e9.jpg, skipping this image.
# Mask not found for 2527060000-jpg_png_jpg.rf.68e49a65d38311d730d14798e5ee3160.jpg, skipping this image.
# Mask not found for 2527060000-jpg_png_jpg.rf.c98baf653fd564940d2cb03158fa4e9b.jpg, skipping this image.
# Mask not found for 2527870000-jpg_png_jpg.rf.18bf90598ff38f01439ddf6776005b98.jpg, skipping this image.
# Mask not found for 2527870000-jpg_png_jpg.rf.cb21148726d7c6ca779b99d2d59db101.jpg, skipping this image.
# Mask not found for 2540330000-jpg_png_jpg.rf.86ec843ab4b42281b163b08740105c26.jpg, skipping this image.
# Mask not found for 2540330000-jpg_png_jpg.rf.8994898e4787ad752dfb861406997706.jpg, skipping this image.
# Mask not found for 2550550000-jpg_png_jpg.rf.b6f43aa9bbb4f0484d784c3c42590f20.jpg, skipping this image.
# Mask not found for 2550550000-jpg_png_jpg.rf.f30b8c8208ffe9eef8c80a7b6f042160.jpg, skipping this image.
# Mask not found for 2551780000-jpg_png_jpg.rf.597fa1da8c9657e0ef16f448255f4850.jpg, skipping this image.
# Mask not found for 2551780000-jpg_png_jpg.rf.5dc79a2917f6ae1f5b704c0e0af60dbc.jpg, skipping this image.
# Mask not found for 2557080000-jpg_png_jpg.rf.482c825084641ac69b994e66eb73ff52.jpg, skipping this image.
# Mask not found for 2557080000-jpg_png_jpg.rf.6fa9441104adb19553e07ab7a94514bd.jpg, skipping this image.
# Mask not found for 2576480000-jpg_png_jpg.rf.9cc9af259279d035471900dc7726a652.jpg, skipping this image.
# Mask not found for 2576480000-jpg_png_jpg.rf.e45da20be3a14c2939764ab2348d6dce.jpg, skipping this image.
# Mask not found for 2592430000-jpg_png_jpg.rf.6bc66ef10ee0ab9d6e6bee32f0193061.jpg, skipping this image.
# Mask not found for 2592430000-jpg_png_jpg.rf.87cbae075e1f87dfa6515fd4ec299f03.jpg, skipping this image.
# Mask not found for 25b27a39-Parhizkar_Marziyeh_2022-06-12142931_jpg.rf.98121f9ce72509e99117b66717d9a273.jpg, skipping this image.
# Mask not found for 25b27a39-Parhizkar_Marziyeh_2022-06-12142931_jpg.rf.b55c689261224410d4ca8c6f4ed0704d.jpg, skipping this image.
# Mask not found for 2613170000-jpg_png_jpg.rf.6837bd64ceb3b8aacedfbc3431993a3e.jpg, skipping this image.
# Mask not found for 2613170000-jpg_png_jpg.rf.c1c6f80eacb4b10b9815b13f802315dd.jpg, skipping this image.
# Mask not found for 2634390000-jpg_png_jpg.rf.0fdc6018e6499328176d5303e2228776.jpg, skipping this image.
# Mask not found for 2634390000-jpg_png_jpg.rf.63d2a779ca2979b391a0052613100056.jpg, skipping this image.
# Mask not found for 2643720000-jpg_png_jpg.rf.a568aa81a12b3d0fe2db6e023678acf0.jpg, skipping this image.
# Mask not found for 2643720000-jpg_png_jpg.rf.ab961230b9072364707a81e733bfa197.jpg, skipping this image.
# Mask not found for 2646710000-jpg_png_jpg.rf.379b2f3768a73a1ee0355296f91dfb4e.jpg, skipping this image.
# Mask not found for 2646710000-jpg_png_jpg.rf.70ca3b35bc0dbe3a357f17f984959a59.jpg, skipping this image.
# Mask not found for 264d0857-Jalilvand_Yones_2022-06-12142921_jpg.rf.ddc480cb37348f9ca5b2d4d0e1ffcb4d.jpg, skipping this image.
# Mask not found for 264d0857-Jalilvand_Yones_2022-06-12142921_jpg.rf.fa9f225e4ac1588455c376d3ec06db1e.jpg, skipping this image.
# Mask not found for 265246f2-Khan_cherli_Mahdi_2022-05-14210129_jpg.rf.d9f8a03ddbece7f121c16f9c20452197.jpg, skipping this image.
# Mask not found for 265246f2-Khan_cherli_Mahdi_2022-05-14210129_jpg.rf.dc4045a6e99f97e70b314df1a4827223.jpg, skipping this image.
# Mask not found for 2668660000-jpg_png_jpg.rf.5c15af3c8e3ddcf3ed3be63d90247d11.jpg, skipping this image.
# Mask not found for 2668660000-jpg_png_jpg.rf.8289e4462cba097099c7be5353b99fbc.jpg, skipping this image.
# Mask not found for 2672940000-jpg_png_jpg.rf.3c57d91c6cd82fda4b528328a216fbea.jpg, skipping this image.
# Mask not found for 2672940000-jpg_png_jpg.rf.ca20656e45a95ee3df542d8b7e32661b.jpg, skipping this image.
# Mask not found for 26ffef0b-Zakeri_Abolfazl_2020-11-14135110_jpg.rf.3b2c69e696730a18f791a95013254054.jpg, skipping this image.
# Mask not found for 26ffef0b-Zakeri_Abolfazl_2020-11-14135110_jpg.rf.8b8ea53a58c894c81e05422872b27c89.jpg, skipping this image.
# Mask not found for 270844d9-RAHIMI_ZAHRA_2020-07-08192634_jpg.rf.4aab7a6c1c559c347e4b8e67163ada24.jpg, skipping this image.
# Mask not found for 270844d9-RAHIMI_ZAHRA_2020-07-08192634_jpg.rf.6e3f9382dae6c34560814bacd53b0449.jpg, skipping this image.
# Mask not found for 270844d9-RAHIMI_ZAHRA_2020-07-08192634_jpg.rf.e467cf11ec20d0a3cbf6f2cd4782d9bb.jpg, skipping this image.
# Mask not found for 270844d9-RAHIMI_ZAHRA_2020-07-08192634_jpg.rf.fedcc4c251667a265090f30593fd2b7c.jpg, skipping this image.
# Mask not found for 2726160000-jpg_png_jpg.rf.1ee0201c9c2306906f3c7d4d4b14d8da.jpg, skipping this image.
# Mask not found for 2726160000-jpg_png_jpg.rf.4d64262e32f007b60073b58a8a2b2eaa.jpg, skipping this image.
# Mask not found for 2766160000-jpg_png_jpg.rf.28d2939b34acdefc6c56912cfef67cf7.jpg, skipping this image.
# Mask not found for 2766160000-jpg_png_jpg.rf.d7dadecc40fb0862781b37e4543929ef.jpg, skipping this image.
# Mask not found for 276690000-jpg_png_jpg.rf.46c6d085f017f19bb91a613b647f7c21.jpg, skipping this image.
# Mask not found for 276690000-jpg_png_jpg.rf.578fc33c869843d8d6b23282b3ebb2fa.jpg, skipping this image.
# Mask not found for 2777550000-jpg_png_jpg.rf.256c2a675bd131f92f07d1ec588d8aa8.jpg, skipping this image.
# Mask not found for 2777550000-jpg_png_jpg.rf.60694b8c5fd1d734550d3a38bc201074.jpg, skipping this image.
# Mask not found for 2778050000-jpg_png_jpg.rf.0ed0c30960236be054da3529cb66f26e.jpg, skipping this image.
# Mask not found for 2778050000-jpg_png_jpg.rf.52c7960a205bcdc7df0ef8bab3fde506.jpg, skipping this image.
# Mask not found for 2795000000-jpg_png_jpg.rf.24a843487eca88304a6bcbff808546bd.jpg, skipping this image.
# Mask not found for 2795000000-jpg_png_jpg.rf.3195cf731435639041917d12cf63ebfb.jpg, skipping this image.
# Mask not found for 2801440000-jpg_png_jpg.rf.40098a11f4fc608a434b021219c733ac.jpg, skipping this image.
# Mask not found for 2801440000-jpg_png_jpg.rf.4a8a772e16a3ab234ea7fc2c9245666f.jpg, skipping this image.
# Mask not found for 2817620000-jpg_png_jpg.rf.6e63322c61354fb5b2ed23983a623f8f.jpg, skipping this image.
# Mask not found for 2817620000-jpg_png_jpg.rf.e5f1fe99082503d7ea17ff36cd981512.jpg, skipping this image.
# Mask not found for 2844500000-jpg_png_jpg.rf.247a451ceea0401c5e4df0c601d023c1.jpg, skipping this image.
# Mask not found for 2844500000-jpg_png_jpg.rf.ed24b8444ec2355b840dbf035ecc759c.jpg, skipping this image.
# Mask not found for 2850920000-jpg_png_jpg.rf.0d00d33d93b91a68cd4e0ca300149a84.jpg, skipping this image.
# Mask not found for 2850920000-jpg_png_jpg.rf.54e11dd9ef5426be1ab786c4bbecf76f.jpg, skipping this image.
# Mask not found for 2850930000-jpg_png_jpg.rf.adf0a30821c3f8cf4221bf2f8e000989.jpg, skipping this image.
# Mask not found for 2850930000-jpg_png_jpg.rf.e7f506ef2fff7f715120efb236d4d2af.jpg, skipping this image.
# Mask not found for 2859420000-jpg_png_jpg.rf.17715f0eefbec4bdf7edf4e834310b37.jpg, skipping this image.
# Mask not found for 2859420000-jpg_png_jpg.rf.76689b443e69ae029323e65394c52748.jpg, skipping this image.
# Mask not found for 2863400000-jpg_png_jpg.rf.013e4df7bcfe6c190f4b94646b3a9850.jpg, skipping this image.
# Mask not found for 2863400000-jpg_png_jpg.rf.8fcdd08fab5e31003f09555aa8c4c843.jpg, skipping this image.
# Mask not found for 288890000-jpg_png_jpg.rf.408d278b8cb0cf87d6f6487fa858153b.jpg, skipping this image.
# Mask not found for 288890000-jpg_png_jpg.rf.764b85310d93329aeb9ba305f13c8558.jpg, skipping this image.
# Mask not found for 2899820000-jpg_png_jpg.rf.3a60a07b35c45526da407f3cb882c297.jpg, skipping this image.
# Mask not found for 2899820000-jpg_png_jpg.rf.b0b37d4b6ac75ca6faa6e9bf72fa8ebe.jpg, skipping this image.
# Mask not found for 2911280000-jpg_png_jpg.rf.59b0a14f22c9562350e2d7c6fda2dba0.jpg, skipping this image.
# Mask not found for 2911280000-jpg_png_jpg.rf.cb9023f49891485621f0320e5785d6bb.jpg, skipping this image.
# Mask not found for 2912340000-jpg_png_jpg.rf.9d9a5e426c99aa1c5ff53dc3ed59dffd.jpg, skipping this image.
# Mask not found for 2912340000-jpg_png_jpg.rf.b2a33bb8a0348840468ce39f5623e11a.jpg, skipping this image.
# Mask not found for 2912570000-jpg_png_jpg.rf.1c6cb6fd9695b7db0c89d99853e44e89.jpg, skipping this image.
# Mask not found for 2912570000-jpg_png_jpg.rf.48fa415c6878b7d50cf102e2e7f6e207.jpg, skipping this image.
# Mask not found for 2933510000-jpg_png_jpg.rf.3df16a2edfeca4cccfcbbd3330ce8013.jpg, skipping this image.
# Mask not found for 2933510000-jpg_png_jpg.rf.e34bc86d3fd515dd44a5ae9b70c8fd47.jpg, skipping this image.
# Mask not found for 2934810000-jpg_png_jpg.rf.31a28f56572f55ff26775ed625d4e137.jpg, skipping this image.
# Mask not found for 2934810000-jpg_png_jpg.rf.5e91ed9883f98e0b7c5e01a38dac3785.jpg, skipping this image.
# Mask not found for 2938520000-jpg_png_jpg.rf.a511559c531f0829ed50bdc7776875fb.jpg, skipping this image.
# Mask not found for 2938520000-jpg_png_jpg.rf.c82401b346c6d3f1baa08f6f8691b8d8.jpg, skipping this image.
# Mask not found for 2945550000-jpg_png_jpg.rf.623781f9404ebaa10c936016ea8999d7.jpg, skipping this image.
# Mask not found for 2945550000-jpg_png_jpg.rf.ef71abb6beb618ef46f4e814e42984f4.jpg, skipping this image.
# Mask not found for 2949130000-jpg_png_jpg.rf.ba3c579ff85d92d2a85e770a6edfe874.jpg, skipping this image.
# Mask not found for 2949130000-jpg_png_jpg.rf.cd7ee7a195db7bf9dfbaab175af7bb74.jpg, skipping this image.
# Mask not found for 2955970000-jpg_png_jpg.rf.1a0ea3bd6faa78424f4da2bfb06d10a4.jpg, skipping this image.
# Mask not found for 2955970000-jpg_png_jpg.rf.99d1c22d00da95452c5a9eb8ee5cdf21.jpg, skipping this image.
# Mask not found for 2966060000-jpg_png_jpg.rf.0b57b0fcb2b5f18a70fe94e78c5fe5d6.jpg, skipping this image.
# ...
# Mask not found for cropped_KHUSHDEEP-SINGH_2023-10-20185339_1_png.rf.dfa4621e3899dc7411af052becf0e785.jpg, skipping this image.
# Mask not found for cropped_KULDEEP-KAUR_2023-10-20161845_1_png.rf.033f460025915a31e7f4b7a893d2c88d.jpg, skipping this image.
# Mask not found for cropped_KULDEEP-KAUR_2023-10-21123855_1_png.rf.bb4a7523a6060a03e1bb05ef4b579c81.jpg, skipping this image.
# Mask not found for cropped_KULDEEP-SINGH_2023-10-20144148_1_png.rf.55a2d83d241b8e54e4ff71ef13a6ca8d.jpg, skipping this image.
# Mask not found for cropped_Kuldeep-Singh_2023-10-26184048_1_png.rf.8808cb510517013b7658d9032d5de0a3.jpg, skipping this image.
# Mask not found for cropped_KULWANT-KAUR_2023-10-20151253_1_png.rf.2b666387b0ed39f56bf9224e0c28e70b.jpg, skipping this image.
# Mask not found for cropped_KULWANT-KAUR_2023-10-20185733_1_png.rf.c56417d59d9559d92d01e8df71598572.jpg, skipping this image.
# Mask not found for cropped_LAKHVEER-KAUR_2023-10-21110904_1_png.rf.ba4da0dd5681ed347b0e09296080b2be.jpg, skipping this image.
# Mask not found for cropped_LAVKESH-SHARMA_2023-10-20162416_1_png.rf.eaf9d80cdef416df1f33b500c0113154.jpg, skipping this image.
# Mask not found for cropped_LAXMI-DEVI_2023-10-21115549_1_png.rf.e5e50a3fb15e897e6c39a2bedc0f6560.jpg, skipping this image.
# Mask not found for cropped_MANJEET-SINGH_2023-10-20165217_1_png.rf.6815c6dcfd572cc16489cfec09ac3825.jpg, skipping this image.
# Mask not found for cropped_MANJU-BHANDU_2023-10-26155054_1_png.rf.310bbb1a20b65f162cb7496678176ebd.jpg, skipping this image.
# Mask not found for cropped_MANJU-GABA_2023-10-20163119_1_png.rf.633bbe10fed8ff0be07e6e0f8353df5f.jpg, skipping this image.
# Mask not found for cropped_Manju-_2023-10-26154956_1_png.rf.344bb4163298304cafb2c2b5bc490fc9.jpg, skipping this image.
# Mask not found for cropped_Meenakshi-_2023-10-26184006_1_png.rf.30a9bdfc92f622c3c58370571055b3b4.jpg, skipping this image.
# Mask not found for cropped_mohita-_2023-10-21140908_1_png.rf.a3e0746211f24541b43800b634792bdd.jpg, skipping this image.
# Mask not found for cropped_MRS-PETER-_2023-10-20153919_1_png.rf.28d7564d943196f277ec2f82ef09ab74.jpg, skipping this image.
# Mask not found for cropped_NACCHATAR-SINGH_2023-10-21124448_1_png.rf.64089ad93a6c39330e534d17d26b8988.jpg, skipping this image.
# Mask not found for cropped_NAVJOT-SINGH_2023-10-21135822_1_png.rf.0fe29f336a0a07caffd1b36278d41747.jpg, skipping this image.
# Mask not found for cropped_OM-PARKASH-AZAD_2023-10-20164354_1_png.rf.9518ed0e0402ff54ea2567ae3268af8a.jpg, skipping this image.
# Mask not found for cropped_PARAMJEET-KAUR_2023-10-20191723_1_png.rf.5a60a6ad1e589545cf140a17befdd9a7.jpg, skipping this image.
# Mask not found for cropped_PARAMJEET-KAUR_2023-10-21124507_1_png.rf.595d03bad616fb8c8af12a82a1c74a80.jpg, skipping this image.
# Mask not found for cropped_PARBODH-CHAND_2023-10-20185136_1_png.rf.b4c5f046180e2af4d2915f388e2b5917.jpg, skipping this image.
# Mask not found for cropped_PARMJEET-KAUR_2023-10-20162024_1_png.rf.45eb9d4043749d265eeb3639993c70f3.jpg, skipping this image.
# Mask not found for cropped_poonam-mittal_2023-10-21152850_1_png.rf.5eaecbb84569095c2567e4ea2beb290b.jpg, skipping this image.
# Mask not found for cropped_PRABHKIRAT-DHILLON_2023-10-20145225_1_png.rf.97fe4d97db2a473d65012ece2b59a23e.jpg, skipping this image.
# Mask not found for cropped_RAJANDEEP-KAUR_2023-10-21115531_1_png.rf.fed34c06cd5eb7362da8e13204b2142b.jpg, skipping this image.
# Mask not found for cropped_RAJANDEEP-SINGH_2023-10-21124231_1_png.rf.9e5f774a8aa00d88e71a19f335c58ee2.jpg, skipping this image.
# Mask not found for cropped_Rajwinder-Bagam_2023-10-26182043_1_png.rf.c1c45b3988d586f16b92be26ae19517e.jpg, skipping this image.
# Mask not found for cropped_RAKESH-KUMAR_2023-10-20190811_1_png.rf.27f038948555872c48cc8fe7a1300923.jpg, skipping this image.
# Mask not found for cropped_RAMA-NAND_2023-10-20152043_1_png.rf.df8ee59bb53de4dba01e6ff199741252.jpg, skipping this image.
# Mask not found for cropped_RAMANDEEP-KAUR_2023-10-21115341_1_png.rf.915c004b5b12cf3deb944581176520cd.jpg, skipping this image.
# Mask not found for cropped_RAMJI-DAS_2023-10-21124753_1_png.rf.252d2d5ad564cfab88f7c3d07af1bf91.jpg, skipping this image.
# Mask not found for cropped_Ravi-kumar_2023-10-26154101_1_png.rf.ba3ffe8dd07e09337dda15b6f619238c.jpg, skipping this image.
# Mask not found for cropped_Resham-Singh_2023-10-21160819_1_png.rf.26b1fef74d53460e6e923b5390f77444.jpg, skipping this image.
# Mask not found for cropped_RUPINDER-KAUR_2023-10-21115608_1_png.rf.2c6b97a145d54676e8ff0937a51dbca3.jpg, skipping this image.
# Mask not found for cropped_RUSHIL-KUMAR_2023-10-21152048_1_png.rf.073203499c243a282a3241732a18aff8.jpg, skipping this image.
# Mask not found for cropped_SANTOSH-DEVI_2023-10-21110750_1_png.rf.89390c4549f4c8f94acd3b72bb89c5ef.jpg, skipping this image.
# Mask not found for cropped_SANTOSH-DEVI_2023-10-26164025_1_png.rf.ee01a3c981594dbcb3020f8b1a23e695.jpg, skipping this image.
# Mask not found for cropped_SARBJEET-KAUR_2023-10-26163828_1_png.rf.c5c75425761119568e6aee03b5aa180c.jpg, skipping this image.
# Mask not found for cropped_SEEMA-PAL_2023-10-26163127_1_png.rf.2c82b8fbe43fe6584b8f726d0afadf09.jpg, skipping this image.
# Mask not found for cropped_SHANKARJEET-SINGH_2023-10-21141822_1_png.rf.47225fa2d4f2ed1e9bf804960af6e4c5.jpg, skipping this image.
# Mask not found for cropped_SHARANDEEP-SINGH_2023-10-26161152_1_png.rf.01eac35e7913f56714f641c47c447aab.jpg, skipping this image.
# Mask not found for cropped_SHARDA-_2023-10-26161130_1_png.rf.84d4f4d3cb92167c503287af6818c110.jpg, skipping this image.
# Mask not found for cropped_SHASHI-BALA_2023-10-20191331_1_png.rf.592ca648946a713f1407a826d56251a7.jpg, skipping this image.
# Mask not found for cropped_SHIVBAHDUR-PAL_2023-10-26160205_1_png.rf.d270af167491ed2376bf854a9c279fd2.jpg, skipping this image.
# Mask not found for cropped_SIMRANJEET-KAUR_2023-10-20150826_1_png.rf.8965c1411cb6ea11ec447d854db03092.jpg, skipping this image.
# Mask not found for cropped_SUKHDEEP-SINGH_2023-10-20145907_1_png.rf.ef3c626ecc703a007ee6d347520834e4.jpg, skipping this image.
# Mask not found for cropped_SUKHJIT-KAUR_2023-10-20145701_1_png.rf.b44c44a6d3ec7dcb26600cb23d115c7f.jpg, skipping this image.
# Mask not found for cropped_Sukhveer-Singh_2023-10-26181803_1_png.rf.806911837c5e03ae4a817a5453a9acfe.jpg, skipping this image.
# Mask not found for cropped_SURINDER-KAUR_2023-10-20155852_1_png.rf.e15da477abe6068898e4b28eb1b6ca13.jpg, skipping this image.
# Mask not found for cropped_SURJEET-SINGH_2023-10-21115406_1_png.rf.40bbf2833a6eeab9a7524f0fa7a73f9d.jpg, skipping this image.
# Mask not found for cropped_SURJIT-SINGH_2023-10-20190440_1_png.rf.360684f96620d178f8f04de90a13c025.jpg, skipping this image.
# Mask not found for cropped_TARANJIT-SINGH_2023-10-20155807_1_png.rf.61aff31f809aee51b49f87b93c1520c1.jpg, skipping this image.
# Mask not found for cropped_Veena-Watts_2023-10-26184104_1_png.rf.729435366947d6cc2e45f00b5a192a22.jpg, skipping this image.
# Mask not found for cropped_Vidya-devi_2023-10-26184639_1_png.rf.3c5ba5472f629d53fbcbd7d4af507b04.jpg, skipping this image.
# Mask not found for cropped_VIKRAMJEET-SINGH_2023-10-21152545_1_png.rf.3878b5f6e51c97275b8368557ae84870.jpg, skipping this image.
# Mask not found for cropped_VINAYAK-PAROLAKAR_2023-10-20163706_1_png.rf.770b6942d8e2f246bb332121ca036c93.jpg, skipping this image.
# Mask not found for cropped_VINAYAK-PAROLAKAR_2023-10-20183323_1_png.rf.94e961772dfcde21a0008b6bd69ea2fb.jpg, skipping this image.
# Mask not found for cropped_VINEY-_2023-10-21132220_1_png.rf.0b4f2a1c79250210f5843dfe766494b0.jpg, skipping this image.
# Mask not found for d0a164d8-DERAKHSHI_MASOOMEH_2020-08-09181006_jpg.rf.87b989de9c0e585fa90c6201a622b6a8.jpg, skipping this image.
# Mask not found for d27f0303-SAKHAEE_ALI_2020-08-02194209_jpg.rf.dcf20ff4998113f91c0fdeac423c68ae.jpg, skipping this image.
# Mask not found for d2b9aa9e-ROSTAMI_FATEMEH_2020-08-19111202_jpg.rf.f9ea9aab74bca46d2fd7344520b26a22.jpg, skipping this image.
# Mask not found for d35aae7a-Salmanzade_Mostafa_2022-06-12140638_jpg.rf.bd37badfbbce76301b1a9ee71381e792.jpg, skipping this image.
# Mask not found for d3dc9ee8-Farmahini_Farahani_Marziye_63yo_02062021_102216_jpg.rf.c0a6bd750eaa6b26a6540acca8cb1871.jpg, skipping this image.
# Mask not found for d7af0daa-RAHMANI_MASUME_2020-07-21191026_jpg.rf.1d672a96e452b93aacc8ef57af2dbabe.jpg, skipping this image.
# Mask not found for d7b31d77-Jafari_Ahmad_36yo_01062021_102902_jpg.rf.47d71d44d3edd6c51e78311e32e3440e.jpg, skipping this image.
# Mask not found for d7d85870-Bohrani_Raziyeh_59yo_31052021_114345_jpg.rf.9029b9ac4636553e27af9736e65b2ef2.jpg, skipping this image.
# Mask not found for daf95006-TABATABAE_ALI_2020-08-24210522_jpg.rf.1004564a8143c66af85f41d46265b375.jpg, skipping this image.
# Mask not found for daf95006-TABATABAE_ALI_2020-08-24210522_jpg.rf.fa74e7d6c47ae441c65101c4f18388b0.jpg, skipping this image.
# Mask not found for dbb4370c-Khodaei_Shahrokh_60yo_02062021_151932_jpg.rf.890cdc82ed60a740be5c7965fd33fd98.jpg, skipping this image.
# Mask not found for dbb4370c-Khodaei_Shahrokh_60yo_02062021_151932_jpg.rf.a919c60518b5bbf256c5951edbdb3f4d.jpg, skipping this image.
# Mask not found for dc7ae772-PIRI_NAJME_2020-02-18184406_jpg.rf.c743936ff158576c0eca691ca90bf669.jpg, skipping this image.
# Mask not found for df33db5f-MASOOMI_AMINEH_2020-06-28182210_jpg.rf.65b3a3cbb394469d208ea5baa618821b.jpg, skipping this image.
# Mask not found for dfa58a0e-RAFIEE_ARTIN_2020-08-04183314_jpg.rf.b8443b8ab33e08f682604f7f26cdb3e7.jpg, skipping this image.
# Mask not found for dfbd2a35-Rezaee_Meysam_2022-06-12141233_jpg.rf.264aeda488ef5bacfa2b27c491392c20.jpg, skipping this image.
# Mask not found for e433185c-SEDIGHI_SARA_2020-08-11102834_jpg.rf.a6637fe1f805266c703823294282d40f.jpg, skipping this image.
# Mask not found for e43464bf-SHIRKHANI_REZA_2020-07-15185916_jpg.rf.5203e8f3211054b2cf205cb12b19ec89.jpg, skipping this image.
# Mask not found for e43464bf-SHIRKHANI_REZA_2020-07-15185916_jpg.rf.bc2cb0f83cc68dabb22bf7cc450afb44.jpg, skipping this image.
# Mask not found for e490c904-Mehr_varz_Raziyeh_2022-06-12141119_jpg.rf.04eb32b91a4d15b9c4f0e353edbcfdd4.jpg, skipping this image.
# Mask not found for e7a00e21-Heydari_Roghayeh_2022-06-12141430_jpg.rf.9c285718b040bdd24119f51b257c73d1.jpg, skipping this image.
# Mask not found for e8706b42-Shafaghi_Mehrdad_2022-06-12142121_jpg.rf.43f3e17adfe09458c828e9b1301dea9b.jpg, skipping this image.
# Mask not found for e9491a32-Alimardani_Alireza_2022-06-12141740_jpg.rf.3245abfe15938eb7c7140cc85c329a0a.jpg, skipping this image.
# Mask not found for ea08aac0-MARAGHI_GISOO_2020-06-10182013_jpg.rf.4b1b43fef5921ad06f22a6de8ab5d47a.jpg, skipping this image.
# Mask not found for ed4dc4d8-BASHIRI_SAJAD_2020-07-29103041_jpg.rf.538e8359d21c28757aa5eff8e453c837.jpg, skipping this image.
# Mask not found for ede4e0ac-Imandar_Maryam_2022-06-12142539_jpg.rf.df82a0ae9243f7e9c80504cf438648d9.jpg, skipping this image.
# Mask not found for eeb607e4-Roshanaee_Sedigheh_2022-06-12141303_jpg.rf.673b99cfe6e96a9f05e11182742aa88a.jpg, skipping this image.
# Mask not found for eec871f7-Kazemi_Roya_2022-06-12142749_jpg.rf.179b9ab2f3e880626ee8ea69d182222c.jpg, skipping this image.
# Mask not found for f0759c1a-FALAHI_PARISA_2020-07-01203804_jpg.rf.54980fe5edec34ee5b297e01982da5f6.jpg, skipping this image.
# Mask not found for f18f62a5-MALEKI_MARYAM_2020-06-20195622_jpg.rf.1155d8290ed07744bbcb984ddfff55c3.jpg, skipping this image.
# Mask not found for f1bb9e4a-MOHAMADI_SANAZ_2020-08-12202441_jpg.rf.2a578101c99b326e8b2f2f73840e752f.jpg, skipping this image.
# Mask not found for f354f38f-MOGHADAM_SEDIGHE_2020-07-07195327_jpg.rf.6d25cea1feee75f04bdf2e2e7550311d.jpg, skipping this image.
# Mask not found for f36813c6-Delparvar_Nasim_2022-05-14183633_jpg.rf.993492a33c9ad3c60b901af9f0f230c2.jpg, skipping this image.
# Mask not found for f4257bd2-Cheraghali_Fatemeh_2020-09-01120434_jpg.rf.8c9e92b97f02ce8a5e79c3f677b93ff3.jpg, skipping this image.
# Mask not found for f483da40-NADERI_AMIR_2020-06-10190539_jpg.rf.f2b6be01357354781e7fc48a31a6a04b.jpg, skipping this image.
# Mask not found for f5f2b9d9-PANAHI_HOSEIN_2020-08-15115131_jpg.rf.474cea2c0c2793fcf1b4ce6a836b084f.jpg, skipping this image.
# Mask not found for f6a9a993-Ebrahimi_khomami_Shakiba_24yo_09062021_142825_jpg.rf.1fced4421ed919a2743e26955890c9a6.jpg, skipping this image.
# Mask not found for f98ce873-RAFIE_RADIN_2020-08-04182713_jpg.rf.f97e75bad6cd2d8b212a621a30664a23.jpg, skipping this image.
# Mask not found for f9e524ae-Hoseynzadeh_Sakineh_2022-06-12142132_jpg.rf.102ec6591ab69c9e9bf9fd2a517651ea.jpg, skipping this image.
# Mask not found for fa85e939-MAJIDI_ALIREZA_2020-07-05122036_jpg.rf.238058f919e05efddea07157d0becc26.jpg, skipping this image.
# Mask not found for fa89d7dd-FATHOLAHI_FATEME_2020-08-16112532_jpg.rf.2b6b627741ff7c06d1336c3cde2d3923.jpg, skipping this image.
# Mask not found for fa89d7dd-FATHOLAHI_FATEME_2020-08-16112532_jpg.rf.6ee2c4014da56fdda8fa0390e570f93c.jpg, skipping this image.
# Mask not found for fad43613-Rezaee_Mostafa_2022-06-12142824_jpg.rf.c0bfe75b46bdd4b014fa7879932a4014.jpg, skipping this image.
# Mask not found for fb7b73cd-SAHEBI_FATEMEH_2020-08-18203613_jpg.rf.d7bc642ac187ae57d7df67111fefb818.jpg, skipping this image.
# Mask not found for fc3ca101-Mohamadi_Fatemeh_2022-05-14192255_jpg.rf.48235f429af3ac40bde4ce17e69b8f9c.jpg, skipping this image.
# Mask not found for fdcd1b09-BORJSAZ_GOLAndam_2020-06-09112003_jpg.rf.c05830a085db00283cf1ddda351e7793.jpg, skipping this image.
# Mask not found for ff568346-Khalili_nia_Mehri_35yo_07022021_111533_jpg.rf.c3f1c14f73bb52fd72a4bb51c66084d2.jpg, skipping this image.
# Mask not found for ffa16c16-Hoseyni_Habibe_48yo_31052021_130138_jpg.rf.e73abd0bfb4598018281297ed753f4c4.jpg, skipping this image.
# Mask not found for valid_mask, skipping this image.
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 ━━━━━━━━━━━━━━━━━━━━ 6s 0us/step
#
# Epoch 1/20
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 196
#     193 metrics_callback = MetricsCallback(total_batches=total_batches)
#     195 # Train the model with early stopping
# --> 196 history = model.fit(
#     197     X_train, y_train,
#     198     epochs=20,               # Number of epochs
#     199     batch_size=batch_size,   # Batch size of 16
#     200     validation_data=(X_valid, y_valid),
#     201     callbacks=[metrics_callback, early_stopping],  # Add early_stopping to the callbacks list
#     202     verbose=0                # Suppress default Keras logging
#     203 )
#     205 # Save the model
#     206 model.save('dental_xray_vgg16_unet_model.h5')
#
# File ~\anaconda3\Lib\site-packages\keras\src\utils\traceback_utils.py:122, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#     120     # To get the full stack trace, call:
#     121     # `keras.config.disable_traceback_filtering()`
# --> 122     raise e.with_traceback(filtered_tb) from None
#     123 finally:
#     124     del filtered_tb
#
# File ~\anaconda3\Lib\site-packages\keras\src\models\functional.py:244, in Functional._adjust_input_rank(self, flat_inputs)
#     242             adjusted.append(ops.expand_dims(x, axis=-1))
#     243             continue
# --> 244     raise ValueError(
#     245         f"Invalid input shape for input {x}. Expected shape "
#     246         f"{ref_shape}, but input has incompatible shape {x.shape}"
#     247     )
#     248 # Add back metadata.
#     249 for i in range(len(flat_inputs)):
#
# ValueError: Exception encountered when calling Functional.call().
#
# Invalid input shape for input Tensor("data:0", shape=(16,), dtype=float32). Expected shape (None, 256, 256, 3), but input has incompatible shape (16,)
#
# Arguments received by Functional.call():
#   • inputs=tf.Tensor(shape=(16,), dtype=float32)
#   • training=True
#   • mask=None
